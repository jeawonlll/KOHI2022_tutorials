# %% [markdown]
# <a href="https://colab.research.google.com/github/jeawonlll/KOHI2022_tutorials/blob/main/20221001/KOHI_221001_%EC%8B%A4%EC%8A%B5%EC%BD%94%EB%93%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #KOHI 2022 10/1 실습 코드
# ## 실습 내용
#
#
# *   데이터 클랜징 및 Cohort 분석
#   * 데이터 클랜징 - 이상값 제거, Outlier 처리
#   * Cohort 분석 - 연령대별 통계분석, 성별에 따른 통계분석, ICU Type에 따른 통계분석
# *   데이터 레이블링 및 학습 데이터 생성
#   * 데이터 레이블링 - 사망, 저혈압
#   * 시계열 형태의 학습 데이터 만들기

# %% [markdown]
# # 데이터 클랜징 - 이상값 제거, Outlier 처리

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Data Download
FILE_IDS = ["1-91Ad_3yQQ0T6ROnlxqbbgEFc6tiZAsY",
            "1-RbUxW2hF2ayWDhkMqGfKZvzEKwiLqQX",
            "1r76_XuYikaeswLAIpIbPpkx_kXgJob3a",
            "1-I25PxwI6qpDrNtDJD_jEnLl_MXh9hjH",
            "1-3YZEp8xFYplMjvFSfzb637WwA8OwW_2",
            "1-HhOwcDMse4BevovRkxOBICe5zZ3YraZ",
            "1GO4MIIzgNOB8zDvtgldU5JdLZbMlnczz"]
FILE_NAMES = ['PATIENTS.csv', 'LABEVENTS.csv', 'CHARTEVENTS.csv',
              'D_ITEMS.csv', 'D_LABITEMS.csv', 'ADMISSIONS.csv', 'ICUSTAYS.csv']
for f_id, f_name in tqdm(zip(FILE_IDS, FILE_NAMES), desc="Download Files...", total=len(FILE_IDS), ncols=75):
  download_file = drive.CreateFile({'id': f_id})
  download_file.GetContentFile(f_name)
# Out:
# Download Files...: 100%|█████████████████████| 7/7 [00:21<00:00,  3.04s/it]

# %%
import os
import csv
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

#ITEMID for MIMIC-III
VITAL_SIGNS = {'PULSE': ['220045', '211'],
               'RESP': ['220210', '618'],
               'SBP': ['220050', '220179', '225309', '51', '455'],
               'DBP': ['220051', '220180', '225310', '8368', '8441'],
               'FiO2': ['223835', '189', '190'],
               'MAP': ['220052', '1321', '438']
               }
LABS = {'BILIRUBIN': ['50885'],
        'LACTATE': ['50813'],
        'pH': ['50820', '50831'],
        'SODIUM': ['50983'],
        'POTASSIUM': ['50971'],
        'CREATININE': ['50912'],
        'WBC': ['51301'],
        'HEMATOCRIT': ['51221']
        }
ITEM_IDS = {
    '220045': 'PULSE', 
    '211': 'PULSE',
    '220210': 'RESP', 
    '618': 'RESP',
    '220050': 'SBP',
    '220179': 'SBP',
    '225309': 'SBP',
    '51': 'SBP',
    '455': 'SBP',
    '220051': 'DBP',
    '220180': 'DBP',
    '225310': 'DBP',
    '8368': 'DBP',
    '8441': 'DBP',
    '223835': 'FiO2',
    '189': 'FiO2',
    '190': 'FiO2',
    '220052': 'MAP',
    '1321': 'MAP',
    '438': 'MAP',
    '50885': 'BILIRUBIN',
    '50813': 'LACTATE',
    '50820': 'pH',
    '50831': 'pH',
    '50983': 'SODIUM',
    '50971': 'POTASSIUM',
    '50912': 'CREATININE',
    '51301': 'WBC',
    '51221': 'HEMATOCRIT'
}

# %%
# Load Chartevents and Labevents Table
CHARTEVENTS = pd.read_csv('CHARTEVENTS.csv', low_memory=False, dtype='str', keep_default_na=False)
LABEVENTS = pd.read_csv('LABEVENTS.csv', low_memory=False, dtype='str', keep_default_na=False)

# %%
# Make Checking float value function
def is_float(value):
  try:
    float(value)
    return True
  except:
    return False

# %%
# Get Only float values for VitalSign
float_VS = CHARTEVENTS[CHARTEVENTS['VALUENUM'].apply(lambda x: is_float(x))].reset_index()
float_VS
# Out:
#            index     ROW_ID SUBJECT_ID HADM_ID ICUSTAY_ID  ITEMID  \
# 0              0     147286       1257  160336     237955  220734
# 1              1     147287       1257  160336     237955  227471
# 2              2     147288       1257  160336     237955  223834
# 3              3     147289       1257  160336     237955  223835
# 4              4     147290       1257  160336     237955  220179
# ...          ...        ...        ...     ...        ...     ...
# 3100999  7241337  329919200      99312  150103     293902  224055
# 3101000  7241338  329919201      99312  150103     293902  224056
# 3101001  7241339  329919202      99312  150103     293902  224057
# 3101002  7241340  329919203      99312  150103     293902  224058
# 3101003  7241341  329919204      99312  150103     293902  224059
#
#                    CHARTTIME            STORETIME   CGID                VALUE  \
# 0        2196-11-21 12:27:00  2196-11-21 13:43:00  20889                    6
# 1        2196-11-21 12:27:00  2196-11-21 13:19:00  20889                 1.01
# 2        2196-11-21 13:00:00  2196-11-21 15:21:00  15652                   10
# 3        2196-11-21 13:00:00  2196-11-21 15:21:00  15652                  100
# 4        2196-11-21 13:21:00  2196-11-21 13:25:00  15652                  139
# ...                      ...                  ...    ...                  ...
# 3100999  2157-05-07 08:04:00  2157-05-07 09:05:00  17250   Occasionally Moist
# 3101000  2157-05-07 08:04:00  2157-05-07 09:05:00  17250              Bedfast
# 3101001  2157-05-07 08:04:00  2157-05-07 09:05:00  17250  Completely Immobile
# 3101002  2157-05-07 08:04:00  2157-05-07 09:05:00  17250  Probably Inadequate
# 3101003  2157-05-07 08:04:00  2157-05-07 09:05:00  17250              Problem
#
#         VALUENUM VALUEUOM WARNING ERROR RESULTSTATUS STOPPED
# 0              6    units       0     0
# 1           1.01                0     0
# 2             10    L/min       0     0
# 3            100                0     0
# 4            139     mmHg       0     0
# ...          ...      ...     ...   ...          ...     ...
# 3100999        3                0     0
# 3101000        1                0     0
# 3101001        1                0     0
# 3101002        2                0     0
# 3101003        1                0     0
#
# [3101004 rows x 16 columns]

# %%
# Get Only float values for Lab
float_LAB = LABEVENTS[LABEVENTS['VALUENUM'].apply(lambda x: is_float(x))].reset_index()
float_LAB
# Out:
#          index    ROW_ID SUBJECT_ID HADM_ID ITEMID            CHARTTIME VALUE  \
# 0            0     24146         55          51248  2138-05-28 18:14:00  27.0
# 1            1     24147         55          51249  2138-05-28 18:14:00  33.0
# 2            2     24148         55          51250  2138-05-28 18:14:00    82
# 3            3     24149         55          51254  2138-05-28 18:14:00   4.5
# 4            4     24150         55          51256  2138-05-28 18:14:00  66.7
# ...        ...       ...        ...     ...    ...                  ...   ...
# 550936  615323  27799406      99231  102589  51275  2149-11-12 12:02:00  29.0
# 550937  615324  27799407      99231  102589  50861  2149-11-13 09:53:00    21
# 550938  615325  27799408      99231  102589  50863  2149-11-13 09:53:00    59
# 550939  615326  27799409      99231  102589  50868  2149-11-13 09:53:00    11
# 550940  615327  27799410      99231  102589  50878  2149-11-13 09:53:00    17
#
#        VALUENUM VALUEUOM FLAG
# 0            27       pg
# 1            33        %
# 2            82       fL
# 3           4.5        %
# 4          66.7        %
# ...         ...      ...  ...
# 550936       29      sec
# 550937       21     IU/L
# 550938       59     IU/L
# 550939       11    mEq/L
# 550940       17     IU/L
#
# [550941 rows x 10 columns]

# %%
# Print examples of non-float values for VitalSign and Lab
nonfloat_VS = CHARTEVENTS[CHARTEVENTS['VALUENUM'].apply(lambda x: not is_float(x))].reset_index()
print(nonfloat_VS.head(5))

nonfloat_LAB = LABEVENTS[LABEVENTS['VALUENUM'].apply(lambda x: not is_float(x))].reset_index()
print(nonfloat_LAB.head(5))
# Out:
#     index    ROW_ID SUBJECT_ID HADM_ID ICUSTAY_ID ITEMID            CHARTTIME  \
# 0  615352  34514448         87  190659     277633   3519  2191-03-17 00:30:00
# 1  615355  34514451         87  190659     277633   3559  2191-03-17 00:30:00
# 2  615356  34514452         87  190659     277633   3568  2191-03-17 00:30:00
# 3  615357  34514453         87  190659     277633   3572  2191-03-17 00:30:00
# 4  615363  34514459         87  190659     277633   3607  2191-03-17 00:30:00
#
#              STORETIME   CGID        VALUE VALUENUM VALUEUOM WARNING ERROR  \
# 0  2191-03-17 01:24:00  20296  Symmetrical
# 1  2191-03-17 01:24:00  20296         None
# 2  2191-03-17 01:24:00  20296       Normal
# 3  2191-03-17 01:24:00  20296       Stable
# 4  2191-03-17 01:24:00  20296    Subcostal
#
#   RESULTSTATUS   STOPPED
# 0               NotStopd
# 1               NotStopd
# 2               NotStopd
# 3               NotStopd
# 4               NotStopd
#    index ROW_ID SUBJECT_ID HADM_ID ITEMID            CHARTTIME    VALUE  \
# 0     16  24162         55          50911  2138-05-29 05:50:00  NotDone
# 1     23  24169         55          51003  2138-05-29 05:50:00    <0.01
# 2     34  24180         55          51464  2138-05-31 03:00:00      NEG
# 3     35  24181         55          51466  2138-05-31 03:00:00      NEG
# 4     36  24182         55          51478  2138-05-31 03:00:00      NEG
#
#   VALUENUM VALUEUOM FLAG
# 0             ng/mL
# 1             ng/mL
# 2             mg/dL
# 3
# 4             mg/dL

# %%
# Get input features only
INPUT_ITEMIDS = list()
for kk, vv in VITAL_SIGNS.items():
  INPUT_ITEMIDS += vv
for kk, vv in LABS.items():
  INPUT_ITEMIDS += vv

INPUT_ITEMIDS = set(INPUT_ITEMIDS)
print(INPUT_ITEMIDS)

input_VS = float_VS[float_VS['ITEMID'].isin(INPUT_ITEMIDS)].reset_index()
input_LAB = float_LAB[float_LAB['ITEMID'].isin(INPUT_ITEMIDS)].reset_index()

print(input_VS)
print(input_LAB)
# Out:
# {'8441', '438', '618', '51301', '220180', '189', '220045', '223835', '51', '220050', '50971', '50912', '51221', '190', '220052', '225309', '50831', '220179', '50813', '455', '50983', '1321', '50820', '211', '220210', '8368', '220051', '225310', '50885'}
#         level_0    index     ROW_ID SUBJECT_ID HADM_ID ICUSTAY_ID  ITEMID  \
# 0             3        3     147289       1257  160336     237955  223835
# 1             4        4     147290       1257  160336     237955  220179
# 2             5        5     147291       1257  160336     237955  220180
# 3             7        7     147293       1257  160336     237955  220210
# 4             8        8     147294       1257  160336     237955  220045
# ...         ...      ...        ...        ...     ...        ...     ...
# 603541  2806811  5569641  255155407      32292  196589     241669    8441
# 603542  2806816  5569650  255155416      32292  196589     241669    8441
# 603543  2806821  5569655  255155421      32292  196589     241669    8441
# 603544  2806826  5569660  255155426      32292  196589     241669    8441
# 603545  2806835  5569671  255155437      32292  196589     241669    8441
#
#                   CHARTTIME            STORETIME   CGID VALUE VALUENUM  \
# 0       2196-11-21 13:00:00  2196-11-21 15:21:00  15652   100      100
# 1       2196-11-21 13:21:00  2196-11-21 13:25:00  15652   139      139
# 2       2196-11-21 13:21:00  2196-11-21 13:25:00  15652    71       71
# 3       2196-11-21 13:22:00  2196-11-21 13:25:00  15652    23       23
# 4       2196-11-21 13:23:00  2196-11-21 13:25:00  15652   123      123
# ...                     ...                  ...    ...   ...      ...
# 603541  2145-03-05 08:00:00  2145-03-05 07:38:00  19689    38       38
# 603542  2145-03-05 09:00:00  2145-03-05 08:49:00  19689    37       37
# 603543  2145-03-05 10:00:00  2145-03-05 10:57:00  19689    30       30
# 603544  2145-03-05 11:00:00  2145-03-05 10:57:00  19689    29       29
# 603545  2145-03-05 13:00:00  2145-03-05 13:25:00  19689    25       25
#
#         VALUEUOM WARNING ERROR RESULTSTATUS   STOPPED
# 0                      0     0
# 1           mmHg       0     0
# 2           mmHg       0     0
# 3       insp/min       0     0
# 4            bpm       0     0
# ...          ...     ...   ...          ...       ...
# 603541      mmHg                             NotStopd
# 603542      mmHg                             NotStopd
# 603543      mmHg                             NotStopd
# 603544      mmHg                             NotStopd
# 603545      mmHg                             NotStopd
#
# [603546 rows x 17 columns]
#         level_0   index    ROW_ID SUBJECT_ID HADM_ID ITEMID  \
# 0             8       8     24154         55          51301
# 1             9       9     24155         55          50813
# 2            16      17     24163         55          50912
# 3            20      21     24167         55          50971
# 4            21      22     24168         55          50983
# ...         ...     ...       ...        ...     ...    ...
# 110731   550918  615304  27798277      99231  168976  51301
# 110732   550926  615313  27798286      99231  168976  50912
# 110733   550930  615317  27798290      99231  168976  50971
# 110734   550931  615318  27798291      99231  168976  50983
# 110735   550933  615320  27799403      99231  102589  51301
#
#                   CHARTTIME VALUE VALUENUM VALUEUOM      FLAG
# 0       2138-05-28 18:14:00  10.3     10.3     K/uL
# 1       2138-05-28 18:19:00   2.0        2   mmol/L
# 2       2138-05-29 05:50:00   0.9       .9    mg/dL
# 3       2138-05-29 05:50:00   4.1      4.1    mEq/L
# 4       2138-05-29 05:50:00   143      143    mEq/L
# ...                     ...   ...      ...      ...       ...
# 110731  2149-08-04 21:59:00   2.9      2.9     K/uL  abnormal
# 110732  2149-08-05 03:53:00   7.3      7.3    mg/dL  abnormal
# 110733  2149-08-05 03:53:00   4.2      4.2    mEq/L
# 110734  2149-08-05 03:53:00   140      140    mEq/L
# 110735  2149-11-12 05:10:00   2.9      2.9     K/uL  abnormal
#
# [110736 rows x 11 columns]

# %% [markdown]
# ### Outlier 제거 실습
#
#
# 1.   정상 범위를 이용한 Outlier 제거
# 2.   IQR를 이용한 Outlier 제거

# %%
# 정상범위를 이용한 Outlier 제거
# Feature별 정상범위 설정
feature_range = dict({
    'AGE': (18, 90),
    'PULSE': (0, 300),
    'RESP': (0, 120),
    'SBP': (0, 300),
    'DBP': (0, 300),
    'MAP': (0, 300),
    'FiO2': (0, 100),
    'BILIRUBIN': (0, 75),
    'LACTATE': (0, 20),
    'SODIUM': (0, 500),
    'POTASSIUM': (0, 15),
    'CREATININE': (0, 20),
    'HEMATOCRIT': (0, 100),
    'WBC': (0, 100),
    'pH': (0, 14),
  })

# %%
# Make function that checking normal range for each value
def is_in_range(value_ranges, feature_key, feature_value):
  if feature_key not in value_ranges:
      raise AssertionError(feature_key)
  value_min, value_max = value_ranges[feature_key]
  return value_min <= feature_value <= value_max

# %%
invalid_input_vs = list()
invalid_input_lab = list()

for (idx, row) in tqdm(input_VS.iterrows(), desc='Filtering VS'):
  itemID = row['ITEMID']
  feature_name = ITEM_IDS[itemID]
  feature_value = float(row['VALUENUM'])
  if is_in_range(feature_range, feature_name, feature_value):
    continue
  else:
    invalid_input_vs.append(idx)

for (idx, row) in tqdm(input_LAB.iterrows(), desc='Filtering LAB'):
  itemID = row['ITEMID']
  feature_name = ITEM_IDS[itemID]
  feature_value = float(row['VALUENUM'])
  if is_in_range(feature_range, feature_name, feature_value):
    continue
  else:
    invalid_input_lab.append(idx)
# Out:
# Filtering VS: 603546it [00:47, 12588.07it/s]
# Filtering LAB: 110736it [00:08, 12784.35it/s]

# %%
print(len(invalid_input_vs))
print(len(input_VS))
valid_input_VS = input_VS.drop(input_VS.index[invalid_input_vs])
print(len(valid_input_VS))

print(len(invalid_input_lab))
print(len(input_LAB))
valid_input_LAB = input_LAB.drop(input_LAB.index[invalid_input_lab])
print(len(valid_input_LAB))
# Out:
# 136
# 603546
# 603410
# 22
# 110736
# 110714

# %%
# split features by hadm_id
hadm_VS = dict()
hadm_LAB = dict()

admissions = pd.read_csv('ADMISSIONS.csv', low_memory=False, dtype='str', keep_default_na=False)
hadm_ids = admissions['HADM_ID'].values

for hadm_id in tqdm(hadm_ids, desc='Split Features by HADM_ID'):
  vs = valid_input_VS[valid_input_VS['HADM_ID'] == hadm_id]
  lab = valid_input_LAB[valid_input_LAB['HADM_ID'] == hadm_id]

  hadm_VS[hadm_id] = vs
  hadm_LAB[hadm_id] = lab
# Out:
# Split Features by HADM_ID: 100%|██████████| 1262/1262 [01:07<00:00, 18.83it/s]

# %%
# IQR을 이용한 Outlier 제거
# Feautre별로 IQR 구하기, Box Plot 그려보기
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
fig1, ax1 = plt.subplots()
sns.boxplot(data = float_VS[float_VS['ITEMID'].isin(VITAL_SIGNS['PULSE'])]['VALUENUM'].values, ax=ax1, orient='h')

# %%
fig1, ax1 = plt.subplots()
sns.boxplot(data = float_VS[float_VS['ITEMID'].isin(VITAL_SIGNS['RESP'])]['VALUENUM'].values, ax=ax1, orient='h')

# %%
fig1, ax1 = plt.subplots()
sns.boxplot(data = float_LAB[float_LAB['ITEMID'].isin(LABS['WBC'])]['VALUENUM'].values, ax=ax1, orient='h')

# %%
def get_min_max_iqr(values):
  q1 = np.quantile(values, 0.25)
  q3 = np.quantile(values, 0.75)
  iqr = q3 - q1
  min = q1 - (1.5 * iqr)
  max = q3 + (1.5 * iqr)
  return min, max

# %%
#IQR을 이용한 Feature별 Range 구하기
def make_feature_range_iqr(feature_range, values, feature_name):
  min, max = get_min_max_iqr(values)
  feature_range[feature_name] = (min, max)
  return feature_range

feature_names = list(VITAL_SIGNS.keys()) + list(LABS.keys())
feature_range = dict()

for feature_name in feature_names:
  if feature_name in VITAL_SIGNS:
    values = float_VS[float_VS['ITEMID'].isin(VITAL_SIGNS[feature_name])]['VALUENUM'].values
  elif feature_name in LABS:
    values = float_LAB[float_LAB['ITEMID'].isin(LABS[feature_name])]['VALUENUM'].values
  
  values = values.astype('float32')
  feature_range = make_feature_range_iqr(feature_range, values, feature_name)

feature_range
# Out:
# {'PULSE': (23.5, 171.5),
#  'RESP': (4.0, 36.0),
#  'SBP': (54.5, 186.5),
#  'DBP': (21.5, 97.5),
#  'FiO2': (-58.99999998509884, 99.3999999910593),
#  'MAP': (37.5, 121.5),
#  'BILIRUBIN': (-3.0500000566244125, 6.150000110268593),
#  'LACTATE': (-1.1999998092651367, 5.199999809265137),
#  'pH': (7.164999723434448, 7.605000257492065),
#  'SODIUM': (127.0, 151.0),
#  'POTASSIUM': (2.649999976158142, 5.450000166893005),
#  'CREATININE': (-0.6500000655651093, 2.950000077486038),
#  'WBC': (-3.049999475479126, 22.149999380111694),
#  'HEMATOCRIT': (17.2375009059906, 44.537498235702515)}

# %%
def is_in_range_iqr(value_ranges, feature_key, feature_value):
  if feature_key not in value_ranges:
      raise AssertionError(feature_key)
  value_min, value_max = value_ranges[feature_key]
  return value_min <= feature_value <= value_max

# %% [markdown]
# # 정규식 실습

# %%
import re

sample_txt = "Hello everyone, this is practical session for KOHI2022. 2022-10-01"

print("[a-z]:", re.findall("[a-z]", sample_txt))
print("[a-z]+:", re.findall("[a-z]+", sample_txt))
print("[0-9]:", re.findall("[0-9]", sample_txt))
print("[0-9]+:", re.findall("[0-9]+", sample_txt))
print("[A-Z]:", re.findall("[A-Z]", sample_txt))
print("[a-zA-Z]+:", re.findall("[a-zA-Z]+", sample_txt))
print("[\w]+:", re.findall("[\w]+", sample_txt))
print("[\d]+:", re.findall("[\d]+", sample_txt))

## Checking valid e-mail address
def email_checking(email):
  try:
    if re.findall(r'[\w.-]+@[\w.-]+.\w+', email)[0] != email:
      print('{}: It is not a valid E-mail address'.format(email))
      return
  except:
      print('{}: It is not a valid E-mail address'.format(email))
      return
  print('{}: It is a valid E-mail address'.format(email))

email_checking('s.hahn@aitrics.com')
# Out:
# [a-z]: ['e', 'l', 'l', 'o', 'e', 'v', 'e', 'r', 'y', 'o', 'n', 'e', 't', 'h', 'i', 's', 'i', 's', 'p', 'r', 'a', 'c', 't', 'i', 'c', 'a', 'l', 's', 'e', 's', 's', 'i', 'o', 'n', 'f', 'o', 'r']
# [a-z]+: ['ello', 'everyone', 'this', 'is', 'practical', 'session', 'for']
# [0-9]: ['2', '0', '2', '2', '2', '0', '2', '2', '1', '0', '0', '1']
# [0-9]+: ['2022', '2022', '10', '01']
# [A-Z]: ['H', 'K', 'O', 'H', 'I']
# [a-zA-Z]+: ['Hello', 'everyone', 'this', 'is', 'practical', 'session', 'for', 'KOHI']
# [\w]+: ['Hello', 'everyone', 'this', 'is', 'practical', 'session', 'for', 'KOHI2022', '2022', '10', '01']
# [\d]+: ['2022', '2022', '10', '01']
# s.hahn@aitrics.com: It is a valid E-mail address

# %%
def phone_checking(phone):
  try:
    if re.findall('[]+[]+[]',phone)[0] != eamil:
      print()
      return
  except:
      print()
      return
  print()

# %%
def is_float_regex(value):
  try:
    float(re.findall("\d+\.\d+|\d+", value)[0])
    return False
  except:
    return True

# %% [markdown]
# # Cohort 분석
# ## - Cohort 정의 & Patients Flow chart
# ## - Cohort 별 데이터 통계 작성

# %%
import pandas as pd
admissions = pd.read_csv('ADMISSIONS.csv')
print(admissions.head(5))
patients = pd.read_csv('PATIENTS.csv')
print(patients.head(5))
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      54          55   190665  2136-04-03 18:35:00  2136-04-05 14:30:00
# 1      83          82   110641  2150-06-24 23:31:00  2150-06-29 15:00:00
# 2      90          87   190659  2191-02-25 20:30:00  2191-04-25 15:18:00
# 3     198         148   199488  2107-09-05 14:58:00  2107-10-08 13:35:00
# 4     630         505   116719  2154-03-30 14:59:00  2154-04-01 16:00:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION   DISCHARGE_LOCATION  \
# 0       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE                 HOME
# 1       NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI                 HOME
# 2       NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI  SHORT TERM HOSPITAL
# 3       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM                  SNF
# 4       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM     HOME HEALTH CARE
#
#   INSURANCE LANGUAGE      RELIGION MARITAL_STATUS              ETHNICITY  \
# 0  Medicare     ENGL      CATHOLIC        MARRIED                  WHITE
# 1259       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 1260       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 1261       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE
#
#             DISCHARGE_LOCATION INSURANCE LANGUAGE       RELIGION  \
# 0                         HOME  Medicare     ENGL       CATHOLIC
# 1                         HOME   Private      NaN   UNOBTAINABLE
# 2          SHORT TERM HOSPITAL   Private      NaN   UNOBTAINABLE
# 3                          SNF  Medicare      NaN   UNOBTAINABLE
# 4             HOME HEALTH CARE   Private     ENGL       CATHOLIC
# ...                        ...       ...      ...            ...
# 1257  REHAB/DISTINCT PART HOSP  Medicaid     SPAN   UNOBTAINABLE
# 1258  REHAB/DISTINCT PART HOSP   Private     ENGL  NOT SPECIFIED
# 1259                      HOME   Private     ENGL       CATHOLIC
# 1260          HOME HEALTH CARE  Medicare     ENGL  NOT SPECIFIED
# 1261                      HOME  Medicare     ENGL       CATHOLIC
#
#          MARITAL_STATUS               ETHNICITY            EDREGTIME  \
# 0               MARRIED                   WHITE                  NaN
# 1                   NaN                   OTHER                  NaN
# 2                   NaN   UNKNOWN/NOT SPECIFIED                  NaN
# 3                   NaN   UNKNOWN/NOT SPECIFIED                  NaN
# 4               MARRIED                   WHITE                  NaN
# ...                 ...                     ...                  ...
# 1257  UNKNOWN (DEFAULT)   UNKNOWN/NOT SPECIFIED  2187-08-20 18:40:00
# 1258            MARRIED                   ASIAN  2111-04-12 23:28:00
# 1259            MARRIED                   WHITE  2180-03-26 21:55:00
# 1260            MARRIED  BLACK/AFRICAN AMERICAN  2194-10-09 10:13:00
# 1261            MARRIED                   WHITE  2195-09-08 16:58:00
#
#                 EDOUTTIME                                         DIAGNOSIS  \
# 0                     NaN                CAROTID STENOSIS\CAROTID ANGIOGRAM
# 1                     NaN                                           NEWBORN
# 2                     NaN                                           NEWBORN
# 3                     NaN                           THROMBOCYTOPENIA;ANEMIA
# 4                     NaN  ACUTE MENTAL STATUS CHANGES/RESPIRATORY DISTRESS
# ...                   ...                                               ...
# 1257  2187-08-20 18:43:00                                S/P GUN SHOT WOUND
# 1258  2111-04-13 03:37:00        STROKE;TELEMETRY;TRANSIENT ISCHEMIC ATTACK
# 1259  2180-03-27 13:04:00                                        CHEST PAIN
# 1260  2194-10-09 15:30:00                               ACUTE RENAL FAILURE
# 1261  2195-09-09 00:24:00                                         PNEUMONIA
#
#       HOSPITAL_EXPIRE_FLAG  HAS_CHARTEVENTS_DATA
# 0                        0                     1
# 1                        0                     1
# 2                        0                     1
# 3                        0                     1
# 4                        0                     1
# ...                    ...                   ...
# 1257                     0                     1
# 1258                     0                     1
# 1259                     0                     1
# 1260                     0                     1
# 1261                     0                     1
#
# [1262 rows x 19 columns]

# %%
from datetime import datetime

NOT_CONVERTED = 'NOT_CONVERTED'

def str2datetime(s):
    def _convert(_s, _dformat):
        try:
            converted_dt = datetime.strptime(_s, _dformat)
        except Exception:
            return NOT_CONVERTED

        return converted_dt

    if isinstance(s, datetime):
        return s

    dformats = [
        '%Y-%m-%d %p %I:%M:%S',
        '%Y-%m-%d %H:%M:%S.%f',
        '%Y-%m-%d %H:%M:%S',
        '%Y-%m-%d %H:%M',
        '%y-%m-%d %H:%M',
        '%Y-%m-%d',
        '%Y%m%d',
        '%Y-%m-%d +%H:%M',
        '%Y%m%d %H%M',
        '%Y%m%d%H%M%S',
        ]

    s = s.split('.')[0]
    s = s.replace('오전', 'am').replace('오후', 'pm')
    for dformat in dformats:
        dt = _convert(s, dformat)
        if dt != NOT_CONVERTED:
            return dt

    return NOT_CONVERTED

# %%
# Inclusion Criteria
## AGE >= 18, First MAP > 65
## Make Patients DataFrame with SUBJECT_ID, HADM_ID, AGE, First MAP
admissions = pd.read_csv('ADMISSIONS.csv')
patients = pd.read_csv('PATIENTS.csv')
patients_info = admissions[['SUBJECT_ID', 'HADM_ID']]
patients_info['AGE'] = ''
patients_info['FIRST_MAP'] = ''

# Update Patient's AGE and MAP
for (idx, row) in tqdm(patients_info.iterrows(), desc='make patients info table'):
  subject_id = row['SUBJECT_ID']
  hadm_id = row['HADM_ID']
  admin_date = admissions[admissions['HADM_ID'] == hadm_id]['ADMITTIME'].values[0]
  dob = patients[patients['SUBJECT_ID'] == subject_id]['DOB'].values[0]
  age = int((str2datetime(admin_date) - str2datetime(dob)).total_seconds() / (3600. * 24 * 365))
  patients_info.loc[idx, 'AGE'] = age

  # If there are no map values, calculate map with sbp & dpb
  # MAP = SBP + 2 (DBP) / 3
  map_list = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['MAP'])]
  map_list.sort_values(by=['CHARTTIME'])
  if len(map_list) == 0:
    sbp_list = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['SBP'])]
    sbp_list.sort_values(by=['CHARTTIME'])
    dbp_list = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['DBP'])]
    dbp_list.sort_values(by=['CHARTTIME'])
    if (len(sbp_list) == 0) or (len(dbp_list) == 0):
      map = np.nan
    else:
      sbp = int(sbp_list['VALUENUM'].values[0])
      dbp = int(dbp_list['VALUENUM'].values[0])
      map = (sbp + (2*dbp)) / 3
  else:
    map = int(map_list['VALUENUM'].values[0])
  
  patients_info.loc[idx, 'FIRST_MAP'] = map

patients_info
# Out:
# make patients info table: 1262it [00:14, 89.72it/s]
#       SUBJECT_ID  HADM_ID AGE  FIRST_MAP
# 0             55   190665  64      104.0
# 1             82   110641   0        NaN
# 2             87   190659   0        NaN
# 3            148   199488  78  63.333333
# 4            505   116719  56       61.0
# ...          ...      ...  ..        ...
# 1257       99830   176834  49         86
# 1258       93784   172532  63         99
# 1259       95413   187979  55  80.333333
# 1260       98644   109643  49       75.0
# 1261       98697   166893  73       88.0
#
# [1262 rows x 4 columns]

# %%
# Find Included Patients and Exclueded Patients
total_patients_n = len(patients_info)
adult_patients = patients_info[patients_info['AGE'] >= 18]
adult_patients_n = len(adult_patients)
map_normal_patients = adult_patients[adult_patients['FIRST_MAP'] > 65]
map_normal_patients_n = len(map_normal_patients)

print('Total Patients Number: ', total_patients_n)
print('Total AGE >= 18 Patients Number: ', adult_patients_n)
print('\t Excluded by AGE: ', total_patients_n - adult_patients_n)
print('Total Normal MAP Patients Number: ', map_normal_patients_n)
print('\t Excluded by MAP: ', adult_patients_n - map_normal_patients_n)
# Out:
# Total Patients Number:  1262
# Total AGE >= 18 Patients Number:  1109
# 	 Excluded by AGE:  153
# Total Normal MAP Patients Number:  914
# 	 Excluded by MAP:  195

# %%
# Make Patients Group by Age
# Age Groups: <30, <40, <50, <60, <70, <80, <90, >=90
group_list = ['<30', '<40', '<50', '<60', '<70', '<80', '<90', '>=90']
age_group = dict()

for group in tqdm(group_list, desc='Grouping by Age'):
  if group == '<30':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 30]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <30: ', len(hadm_ids))
  elif group == '<40':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 40]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <40: ', len(hadm_ids))
  elif group == '<50':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 50]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <50: ', len(hadm_ids))
  elif group == '<60':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 60]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <60: ', len(hadm_ids))
  elif group == '<70':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 70]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <70: ', len(hadm_ids))
  elif group == '<80':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 80]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <80: ', len(hadm_ids))
  elif group == '<90':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 90]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <90: ', len(hadm_ids))
  else:
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] >= 90]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients >=90: ', len(hadm_ids))
# Out:
# Grouping by Age: 100%|██████████| 8/8 [00:00<00:00, 402.86it/s]
# # of Patients <30:  48
# # of Patients <40:  94
# # of Patients <50:  200
# # of Patients <60:  382
# # of Patients <70:  565
# # of Patients <80:  745
# # of Patients <90:  875
# # of Patients >=90:  39

# %%
# Calculate feature statistics for each Group of Patients
# PULSE
feature_statistics = dict()
feature_name = 'PULSE'
for group in tqdm(group_list, desc='Calculate feature statistics by Age Group'):
  group_hadm_ids = age_group[group]
  feature_values = list()
  for hadm_id in group_hadm_ids:
    vs_table = hadm_VS[str(hadm_id)]
    feature_list = list((vs_table[vs_table['ITEMID'].isin(VITAL_SIGNS[feature_name])]['VALUENUM'].values).astype('float32'))
    feature_values += feature_list
  feature_statistics[group] = dict()
  feature_statistics[group][feature_name] = dict({
      'MEAN': np.mean(feature_values),
      'STD': np.std(feature_values),
      'MIN': np.min(feature_values),
      'MAX': np.max(feature_values),
  })
# Out:
# Calculate feature statistics by Age Group: 100%|██████████| 8/8 [00:02<00:00,  3.42it/s]

# %%
feature_statistics
# Out:
# {'<30': {'PULSE': {'MEAN': 100.68296,
#    'STD': 18.467218,
#    'MIN': 28.0,
#    'MAX': 196.0}},
#  '<40': {'PULSE': {'MEAN': 96.06703,
#    'STD': 19.411335,
#    'MIN': 0.0,
#    'MAX': 196.0}},
#  '<50': {'PULSE': {'MEAN': 91.73535,
#    'STD': 19.322868,
#    'MIN': 0.0,
#    'MAX': 196.0}},
#  '<60': {'PULSE': {'MEAN': 90.18136,
#    'STD': 18.485464,
#    'MIN': 0.0,
#    'MAX': 214.0}},
#  '<70': {'PULSE': {'MEAN': 89.340965,
#    'STD': 18.096758,
#    'MIN': 0.0,
#    'MAX': 214.0}},
#  '<80': {'PULSE': {'MEAN': 88.71068,
#    'STD': 17.884577,
#    'MIN': 0.0,
#    'MAX': 214.0}},
#  '<90': {'PULSE': {'MEAN': 88.15716,
#    'STD': 17.771423,
#    'MIN': 0.0,
#    'MAX': 214.0}},
#  '>=90': {'PULSE': {'MEAN': 88.13594,
#    'STD': 19.700163,
#    'MIN': 0.0,
#    'MAX': 160.0}}}

# %% [markdown]
# # 데이터 레이블링 실습
#
#
# 1.   사망 레이블
# 2.   저혈압 레이블

# %%
# Make Label DataFrame with SUBJECT_ID, HADM_ID, LABEL, DEATH_TIME
death_label = map_normal_patients[['SUBJECT_ID', 'HADM_ID']]
admissions = pd.read_csv('ADMISSIONS.csv')
death_label = pd.merge(left = death_label, right = admissions[['HADM_ID', 'DEATHTIME', 'HOSPITAL_EXPIRE_FLAG']], how='left', left_on='HADM_ID', right_on='HADM_ID')
death_label = death_label.rename(columns = {'DEATHTIME': 'DEATH_TIME', 'HOSPITAL_EXPIRE_FLAG': 'LABEL'})

# %%
death_label
# Out:
#      SUBJECT_ID  HADM_ID           DEATH_TIME  LABEL
# 0            55   190665                  NaN      0
# 1           505   103194  2154-08-29 11:10:00      1
# 2           201   161473                  NaN      0
# 3           901   107952                  NaN      0
# 4           540   160169                  NaN      0
# ..          ...      ...                  ...    ...
# 909       99830   176834                  NaN      0
# 910       93784   172532                  NaN      0
# 911       95413   187979                  NaN      0
# 912       98644   109643                  NaN      0
# 913       98697   166893                  NaN      0
#
# [914 rows x 4 columns]

# %%
death_label['LABEL']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 909    0
# 910    0
# 911    0
# 912    0
# 913    0
# Name: LABEL, Length: 914, dtype: int64

# %%
def get_map_with_time(hadm_id):
  map_list = list()
  map_table = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['MAP'])]
  for (idx, row) in map_table.iterrows():
    chart_time = str2datetime(row['CHARTTIME'])
    feature_value = float(row['VALUENUM'])
    map_list.append((chart_time, feature_value))
  return map_list

# %%
def get_sbp_with_time(hadm_id):
  sbp_list = list()
  sbp_table = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['SBP'])]
  for (idx, row) in sbp_table.iterrows():
    chart_time = str2datetime(row['CHARTTIME'])
    feature_value = float(row['VALUENUM'])
    sbp_list.append((chart_time, feature_value))
  return sbp_list

# %%
def get_dbp_with_time(hadm_id):
  dbp_list = list()
  dbp_table = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['DBP'])]
  for (idx, row) in dbp_table.iterrows():
    chart_time = str2datetime(row['CHARTTIME'])
    feature_value = float(row['VALUENUM'])
    dbp_list.append((chart_time, feature_value))
  return dbp_list

# %%
import random
def checking_hypotension(map_list):
  map_list = sorted(map_list, key=lambda x: x[0])
  for idx in range(1, len(map_list)):
    if (map_list[idx-1][1] < 65) and (map_list[idx][1] < 65):
      return True, map_list[idx-1][0]
  
  return False, random.choice(map_list)[0]

# %%
def make_map_with_sbp_dbp(admin_time, disch_time, sbp_list, dbp_list):
  start = admin_time
  end = disch_time
  los = int((end - start).total_seconds() / 3600.)
  map_list = list()
  for i in range(los):
    window_start = start + timedelta(hours=i)
    window_end = window_start + timedelta(hours=1)
    sbps = list(filter(lambda x: window_start <= x[0] <= window_end, sbp_list))
    dbps = list(filter(lambda x: window_start <= x[0] <= window_end, dbp_list))

    if (len(sbps) == 0) or (len(dbps) == 0):
      continue
    sbp = np.mean([x[1] for x in sbps])
    dbp = np.mean([x[1] for x in dbps])
    # MAP = SBP + 2 (DBP) / 3
    map = (sbp + (2*dbp)) / 3
    map_list.append((window_start, map))
  return map_list

# %%
# Make Label DataFrame with SUBJECT_ID, HADM_ID, LABEL, HYPOTENSION_TIME
hypotension_label = map_normal_patients[['SUBJECT_ID', 'HADM_ID']]
hypotension_label['LABEL'] = ''
hypotension_label['HYPOTENSION_TIME'] = ''
admissions = pd.read_csv('ADMISSIONS.csv')
# Make MAP DATA for each patients
hadm_ids = hypotension_label['HADM_ID'].values
for hadm_id in tqdm(hadm_ids, desc='Checking Hypotension'):
  admin_time = str2datetime(admissions[admissions['HADM_ID'] == hadm_id]['ADMITTIME'].values[0])
  disch_time = str2datetime(admissions[admissions['HADM_ID'] == hadm_id]['DISCHTIME'].values[0])
  map_list = get_map_with_time(hadm_id)
  if len(map_list) == 0:
    sbp_list = get_sbp_with_time(hadm_id)
    dbp_list = get_dbp_with_time(hadm_id)

  if len(map_list) != 0:
    event_yn, event_time = checking_hypotension(map_list)
  else:
    map_list = make_map_with_sbp_dbp(admin_time, disch_time, sbp_list, dbp_list)
    event_yn, event_time = checking_hypotension(map_list)

  if event_yn:
    hypotension_label.loc[hypotension_label['HADM_ID'] == hadm_id, 'LABEL'] = 1
    hypotension_label.loc[hypotension_label['HADM_ID'] == hadm_id, 'HYPOTENSION_TIME'] = event_time
  else:
    hypotension_label.loc[hypotension_label['HADM_ID'] == hadm_id, 'LABEL'] = 0
    hypotension_label.loc[hypotension_label['HADM_ID'] == hadm_id, 'HYPOTENSION_TIME'] = event_time

print(hypotension_label)
print(sum(hypotension_label['LABEL'].values))
# Out:
#   File "<ipython-input-48-9635e9a1cb3d>", line 31
#     print(sum(hypotension_label['LABEL'].values)/length(hypotension_label['LABEL'])
#                                                                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
print(sum(hypotension_label['LABEL'].values)/len(hypotension_label['LABEL']))
# Out:
# 0.41575492341356673

# %% [markdown]
# # Input Data 만들기

# %%
# SPLIT Development, Test set with Subject level (8:2)
subject_ids = hypotension_label['SUBJECT_ID'].unique()
pos_subjects = list()
neg_subjects = list()

for subject_id in subject_ids:
  label = sum(hypotension_label[hypotension_label['SUBJECT_ID'] == subject_id]['LABEL'].values)
  if label == 0:
    neg_subjects.append(subject_id)
  else:
    pos_subjects.append(subject_id)

pos_train_idx = random.sample(range(len(pos_subjects)), int(len(pos_subjects) * 0.8))
neg_train_idx = random.sample(range(len(neg_subjects)), int(len(neg_subjects) * 0.8))

print(pos_train_idx)
print(neg_train_idx)

pos_train = list()
pos_test = list()

neg_train = list()
neg_test = list()

for idx, subject_id in enumerate(pos_subjects):
  if idx in pos_train_idx:
    pos_train.append(subject_id)
  else:
    pos_test.append(subject_id)

for idx, subject_id in enumerate(neg_subjects):
  if idx in neg_train_idx:
    neg_train.append(subject_id)
  else:
    neg_test.append(subject_id)

develop_subject = pos_train + neg_train
test_subject = pos_test + neg_test

print(len(develop_subject))
print(len(test_subject))
# Out:
# [284, 253, 318, 34, 188, 105, 267, 175, 26, 123, 280, 213, 124, 182, 263, 312, 8, 311, 107, 47, 330, 106, 48, 238, 86, 239, 177, 208, 30, 257, 67, 117, 178, 149, 210, 1, 97, 58, 87, 214, 325, 281, 221, 166, 222, 183, 96, 137, 65, 31, 70, 200, 145, 99, 19, 298, 167, 316, 0, 56, 191, 216, 138, 37, 160, 271, 283, 141, 93, 273, 293, 14, 4, 46, 112, 42, 115, 250, 127, 155, 111, 244, 71, 39, 40, 170, 64, 150, 129, 223, 314, 88, 151, 291, 25, 113, 45, 173, 241, 135, 122, 10, 68, 215, 2, 153, 292, 329, 270, 18, 29, 72, 118, 125, 304, 274, 323, 313, 102, 327, 201, 261, 24, 77, 194, 161, 76, 84, 286, 251, 134, 258, 27, 185, 148, 209, 230, 212, 282, 235, 247, 61, 218, 285, 54, 83, 196, 242, 163, 260, 295, 174, 302, 57, 132, 226, 326, 287, 5, 44, 108, 136, 12, 13, 232, 128, 254, 236, 224, 277, 119, 22, 256, 219, 184, 114, 288, 180, 95, 227, 294, 36, 220, 91, 264, 147, 92, 317, 303, 296, 290, 104, 279, 28, 101, 193, 203, 33, 228, 139, 305, 144, 15, 51, 116, 121, 300, 73, 245, 156, 50, 52, 322, 248, 243, 142, 103, 89, 9, 69, 328, 49, 172, 11, 63, 186, 225, 176, 307, 7, 268, 158, 315, 133, 59, 217, 237, 297, 249, 234, 275, 62, 100, 41, 289, 140, 74, 3, 246, 202, 130, 85, 120, 146, 262, 265, 164, 187, 306, 90, 309, 131, 75, 60]
# [262, 383, 78, 327, 186, 117, 190, 275, 23, 358, 97, 373, 155, 322, 10, 4, 120, 303, 306, 349, 390, 187, 62, 175, 282, 75, 184, 283, 95, 126, 274, 369, 228, 114, 374, 105, 93, 389, 188, 116, 334, 159, 371, 260, 280, 364, 305, 281, 225, 287, 37, 8, 149, 191, 246, 215, 395, 352, 202, 298, 211, 328, 224, 32, 335, 400, 201, 241, 127, 119, 365, 379, 25, 297, 397, 313, 318, 279, 28, 64, 36, 276, 233, 372, 409, 138, 207, 124, 311, 92, 261, 386, 27, 363, 329, 110, 376, 210, 292, 301, 354, 128, 198, 189, 80, 307, 17, 345, 299, 142, 255, 319, 41, 60, 304, 26, 66, 44, 339, 99, 173, 270, 185, 42, 43, 212, 30, 336, 239, 348, 162, 40, 288, 34, 145, 219, 169, 341, 325, 59, 170, 143, 46, 393, 256, 156, 295, 135, 396, 103, 231, 192, 296, 344, 206, 268, 5, 209, 347, 350, 167, 230, 381, 272, 132, 338, 77, 179, 125, 139, 3, 404, 183, 21, 320, 90, 45, 366, 31, 316, 247, 359, 161, 410, 380, 174, 286, 74, 100, 302, 16, 33, 398, 402, 118, 96, 61, 1, 312, 308, 108, 414, 81, 314, 76, 240, 9, 163, 248, 271, 199, 194, 285, 152, 79, 150, 48, 324, 121, 165, 85, 88, 57, 370, 49, 413, 172, 65, 47, 221, 340, 6, 53, 284, 263, 208, 375, 351, 69, 407, 244, 160, 217, 227, 356, 181, 367, 236, 269, 86, 384, 144, 289, 94, 343, 54, 12, 266, 193, 178, 353, 337, 264, 58, 406, 331, 273, 141, 134, 232, 157, 382, 14, 177, 258, 204, 412, 63, 326, 237, 13, 102, 254, 291, 39, 104, 333, 360, 222, 89, 91, 394, 24, 70, 0, 200, 131, 377, 203, 346, 401, 151, 317, 226, 35, 290, 68, 15, 300, 243, 147, 107, 223, 216, 235, 129, 392, 267, 148, 218, 357, 249, 250, 251, 137, 123, 220, 378, 405, 361, 146, 133]
# 596
# 151

# %%
# Get Features from Admission time to Prediction time
INPUT_FEATURES = list(VITAL_SIGNS.keys()) + list(LABS.keys())
subject_id = develop_subject[2]

hadm_ids = hypotension_label[hypotension_label['SUBJECT_ID'] == subject_id]['HADM_ID'].values
print(len(hadm_ids))
hadm_input = dict()
for hadm_id in tqdm(hadm_ids, desc='make input features'):
  admin_time = str2datetime(admissions[admissions['HADM_ID'] == hadm_id]['ADMITTIME'].values[0])
  print(admin_time)
  label = hypotension_label[hypotension_label['HADM_ID'] == hadm_id]['LABEL']
  event_time = hypotension_label[hypotension_label['HADM_ID'] == hadm_id]['HYPOTENSION_TIME'].values[0]
  print(event_time)
  seq_len = int((event_time - admin_time).total_seconds() / 3600.)
  print(seq_len)

  features = dict()

  vs = hadm_VS[str(hadm_id)]
  lab = hadm_LAB[str(hadm_id)]
  
  for input_kk in INPUT_FEATURES:
    if input_kk == 'MAP':
      continue
    if input_kk in VITAL_SIGNS:
      feature_vv = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS[input_kk])]
      feature_list = list()

      for (idx, row) in feature_vv.iterrows():
        tt = str2datetime(row['CHARTTIME'])
        vv = float(row['VALUENUM'])
        feature_list.append((tt, vv))
    else:
      feature_vv = hadm_LAB[str(hadm_id)][hadm_LAB[str(hadm_id)]['ITEMID'].isin(LABS[input_kk])]
      feature_list = list()

      for (idx, row) in feature_vv.iterrows():
        tt = str2datetime(row['CHARTTIME'])
        vv = float(row['VALUENUM'])
        feature_list.append((tt, vv))
    
    feature_list = sorted(feature_list, key=lambda x: x[0])
    _feature_list = list()

    for seq_id in range(seq_len):
      start = admin_time + timedelta(hours=seq_id)
      end = start + timedelta(hours=1)
      time_features = list(filter(lambda x: start <= x[0] <= end, feature_list))
      if len(time_features) > 0:
        _feature_list.append((start, time_features[-1][1]))
      else:
        _feature_list.append((start, np.nan))

    features[input_kk] = _feature_list
  
  hadm_input[hadm_id] = features
# Out:
# 1
# make input features:   0%|          | 0/1 [00:00<?, ?it/s]
# 2151-02-01 08:45:00
# 2151-02-10 13:45:00
# 221
# make input features: 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]

# %%
features
# Out:
# {'PULSE': [(datetime.datetime(2151, 2, 1, 8, 45), nan),
#   (datetime.datetime(2151, 2, 1, 9, 45), nan),
#   (datetime.datetime(2151, 2, 1, 10, 45), nan),
#   (datetime.datetime(2151, 2, 1, 11, 45), nan),
#   (datetime.datetime(2151, 2, 1, 12, 45), nan),
#   (datetime.datetime(2151, 2, 1, 13, 45), nan),
#   (datetime.datetime(2151, 2, 1, 14, 45), 166.0),
#   (datetime.datetime(2151, 2, 1, 15, 45), 120.0),
#   (datetime.datetime(2151, 2, 1, 16, 45), 111.0),
#   (datetime.datetime(2151, 2, 1, 17, 45), 105.0),
#   (datetime.datetime(2151, 2, 1, 18, 45), 118.0),
#   (datetime.datetime(2151, 2, 1, 19, 45), 124.0),
#   (datetime.datetime(2151, 2, 1, 20, 45), 111.0),
#   (datetime.datetime(2151, 2, 1, 21, 45), 102.0),
#   (datetime.datetime(2151, 2, 1, 22, 45), 97.0),
#   (datetime.datetime(2151, 2, 1, 23, 45), 98.0),
#   (datetime.datetime(2151, 2, 2, 0, 45), 113.0),
#   (datetime.datetime(2151, 2, 2, 1, 45), 124.0),
#   (datetime.datetime(2151, 2, 2, 2, 45), 117.0),
#   (datetime.datetime(2151, 2, 2, 3, 45), 109.0),
#   (datetime.datetime(2151, 2, 2, 4, 45), 122.0),
#   (datetime.datetime(2151, 2, 2, 5, 45), 123.0),
#   (datetime.datetime(2151, 2, 2, 6, 45), 116.0),
#   (datetime.datetime(2151, 2, 2, 7, 45), 141.0),
#   (datetime.datetime(2151, 2, 2, 8, 45), 92.0),
#   (datetime.datetime(2151, 2, 2, 9, 45), 89.0),
#   (datetime.datetime(2151, 2, 2, 10, 45), 94.0),
#   (datetime.datetime(2151, 2, 2, 11, 45), 95.0),
#   (datetime.datetime(2151, 2, 2, 12, 45), 103.0),
#   (datetime.datetime(2151, 2, 2, 13, 45), 99.0),
#   (datetime.datetime(2151, 2, 2, 14, 45), nan),
#   (datetime.datetime(2151, 2, 2, 15, 45), 100.0),
#   (datetime.datetime(2151, 2, 2, 16, 45), 99.0),
#   (datetime.datetime(2151, 2, 2, 17, 45), 107.0),
#   (datetime.datetime(2151, 2, 2, 18, 45), 91.0),
#   (datetime.datetime(2151, 2, 2, 19, 45), 99.0),
#   (datetime.datetime(2151, 2, 2, 20, 45), 96.0),
#   (datetime.datetime(2151, 2, 2, 21, 45), 95.0),
#   (datetime.datetime(2151, 2, 2, 22, 45), 110.0),
#   (datetime.datetime(2151, 2, 2, 23, 45), 109.0),
#   (datetime.datetime(2151, 2, 3, 0, 45), 107.0),
#   (datetime.datetime(2151, 2, 3, 1, 45), 96.0),
#   (datetime.datetime(2151, 2, 3, 2, 45), 92.0),
#   (datetime.datetime(2151, 2, 3, 3, 45), 102.0),
#   (datetime.datetime(2151, 2, 3, 4, 45), 92.0),
#   (datetime.datetime(2151, 2, 3, 5, 45), 98.0),
#   (datetime.datetime(2151, 2, 3, 6, 45), 87.0),
#   (datetime.datetime(2151, 2, 3, 7, 45), 103.0),
#   (datetime.datetime(2151, 2, 3, 8, 45), 97.0),
#   (datetime.datetime(2151, 2, 3, 9, 45), 96.0),
#   (datetime.datetime(2151, 2, 3, 10, 45), 98.0),
#   (datetime.datetime(2151, 2, 3, 11, 45), 90.0),
#   (datetime.datetime(2151, 2, 3, 12, 45), 90.0),
#   (datetime.datetime(2151, 2, 3, 13, 45), 99.0),
#   (datetime.datetime(2151, 2, 3, 14, 45), 93.0),
#   (datetime.datetime(2151, 2, 3, 15, 45), 97.0),
#   (datetime.datetime(2151, 2, 3, 16, 45), 104.0),
#   (datetime.datetime(2151, 2, 3, 17, 45), 90.0),
#   (datetime.datetime(2151, 2, 3, 18, 45), 100.0),
#   (datetime.datetime(2151, 2, 3, 19, 45), 84.0),
#   (datetime.datetime(2151, 2, 3, 20, 45), 93.0),
#   (datetime.datetime(2151, 2, 3, 21, 45), 134.0),
#   (datetime.datetime(2151, 2, 3, 22, 45), 96.0),
#   (datetime.datetime(2151, 2, 3, 23, 45), 139.0),
#   (datetime.datetime(2151, 2, 4, 0, 45), 100.0),
#   (datetime.datetime(2151, 2, 4, 1, 45), 85.0),
#   (datetime.datetime(2151, 2, 4, 2, 45), 84.0),
#   (datetime.datetime(2151, 2, 4, 3, 45), 110.0),
#   (datetime.datetime(2151, 2, 4, 4, 45), 87.0),
#   (datetime.datetime(2151, 2, 4, 5, 45), 100.0),
#   (datetime.datetime(2151, 2, 4, 6, 45), 102.0),
#   (datetime.datetime(2151, 2, 4, 7, 45), 112.0),
#   (datetime.datetime(2151, 2, 4, 8, 45), 99.0),
#   (datetime.datetime(2151, 2, 4, 9, 45), 93.0),
#   (datetime.datetime(2151, 2, 4, 10, 45), 84.0),
#   (datetime.datetime(2151, 2, 4, 11, 45), 88.0),
#   (datetime.datetime(2151, 2, 4, 12, 45), 82.0),
#   (datetime.datetime(2151, 2, 4, 13, 45), 81.0),
#   (datetime.datetime(2151, 2, 4, 14, 45), 93.0),
#   (datetime.datetime(2151, 2, 4, 15, 45), 80.0),
#   (datetime.datetime(2151, 2, 4, 16, 45), 78.0),
#   (datetime.datetime(2151, 2, 4, 17, 45), 85.0),
#   (datetime.datetime(2151, 2, 4, 18, 45), 87.0),
#   (datetime.datetime(2151, 2, 4, 19, 45), 106.0),
#   (datetime.datetime(2151, 2, 4, 20, 45), 101.0),
#   (datetime.datetime(2151, 2, 4, 21, 45), 112.0),
#   (datetime.datetime(2151, 2, 4, 22, 45), nan),
#   (datetime.datetime(2151, 2, 4, 23, 45), 85.0),
#   (datetime.datetime(2151, 2, 5, 0, 45), 83.0),
#   (datetime.datetime(2151, 2, 5, 1, 45), 74.0),
#   (datetime.datetime(2151, 2, 5, 2, 45), 68.0),
#   (datetime.datetime(2151, 2, 5, 3, 45), 63.0),
#   (datetime.datetime(2151, 2, 5, 4, 45), 65.0),
#   (datetime.datetime(2151, 2, 5, 5, 45), 86.0),
#   (datetime.datetime(2151, 2, 5, 6, 45), nan),
#   (datetime.datetime(2151, 2, 5, 7, 45), 70.0),
#   (datetime.datetime(2151, 2, 5, 8, 45), 68.0),
#   (datetime.datetime(2151, 2, 5, 9, 45), 98.0),
#   (datetime.datetime(2151, 2, 5, 10, 45), 106.0),
#   (datetime.datetime(2151, 2, 5, 11, 45), 97.0),
#   (datetime.datetime(2151, 2, 5, 12, 45), 93.0),
#   (datetime.datetime(2151, 2, 5, 13, 45), 99.0),
#   (datetime.datetime(2151, 2, 5, 14, 45), 104.0),
#   (datetime.datetime(2151, 2, 5, 15, 45), 105.0),
#   (datetime.datetime(2151, 2, 5, 16, 45), 89.0),
#   (datetime.datetime(2151, 2, 5, 17, 45), 102.0),
#   (datetime.datetime(2151, 2, 5, 18, 45), 84.0),
#   (datetime.datetime(2151, 2, 5, 19, 45), 89.0),
#   (datetime.datetime(2151, 2, 5, 20, 45), 103.0),
#   (datetime.datetime(2151, 2, 5, 21, 45), 106.0),
#   (datetime.datetime(2151, 2, 5, 22, 45), 112.0),
#   (datetime.datetime(2151, 2, 5, 23, 45), 95.0),
#   (datetime.datetime(2151, 2, 6, 0, 45), 100.0),
#   (datetime.datetime(2151, 2, 6, 1, 45), 102.0),
#   (datetime.datetime(2151, 2, 6, 2, 45), 106.0),
#   (datetime.datetime(2151, 2, 6, 3, 45), 93.0),
#   (datetime.datetime(2151, 2, 6, 4, 45), 86.0),
#   (datetime.datetime(2151, 2, 6, 5, 45), 92.0),
#   (datetime.datetime(2151, 2, 6, 6, 45), nan),
#   (datetime.datetime(2151, 2, 6, 7, 45), 100.0),
#   (datetime.datetime(2151, 2, 6, 8, 45), 91.0),
#   (datetime.datetime(2151, 2, 6, 9, 45), 91.0),
#   (datetime.datetime(2151, 2, 6, 10, 45), 86.0),
#   (datetime.datetime(2151, 2, 6, 11, 45), 93.0),
#   (datetime.datetime(2151, 2, 6, 12, 45), 85.0),
#   (datetime.datetime(2151, 2, 6, 13, 45), nan),
#   (datetime.datetime(2151, 2, 6, 14, 45), 93.0),
#   (datetime.datetime(2151, 2, 6, 15, 45), 105.0),
#   (datetime.datetime(2151, 2, 6, 16, 45), 99.0),
#   (datetime.datetime(2151, 2, 6, 17, 45), 76.0),
#   (datetime.datetime(2151, 2, 6, 18, 45), 81.0),
#   (datetime.datetime(2151, 2, 6, 19, 45), 87.0),
#   (datetime.datetime(2151, 2, 6, 20, 45), 82.0),
#   (datetime.datetime(2151, 2, 6, 21, 45), 79.0),
#   (datetime.datetime(2151, 2, 6, 22, 45), 80.0),
#   (datetime.datetime(2151, 2, 6, 23, 45), 90.0),
#   (datetime.datetime(2151, 2, 7, 0, 45), 93.0),
#   (datetime.datetime(2151, 2, 7, 1, 45), 76.0),
#   (datetime.datetime(2151, 2, 7, 2, 45), 88.0),
#   (datetime.datetime(2151, 2, 7, 3, 45), 97.0),
#   (datetime.datetime(2151, 2, 7, 4, 45), 87.0),
#   (datetime.datetime(2151, 2, 7, 5, 45), 101.0),
#   (datetime.datetime(2151, 2, 7, 6, 45), 104.0),
#   (datetime.datetime(2151, 2, 7, 7, 45), 103.0),
#   (datetime.datetime(2151, 2, 7, 8, 45), nan),
#   (datetime.datetime(2151, 2, 7, 9, 45), 94.0),
#   (datetime.datetime(2151, 2, 7, 10, 45), nan),
#   (datetime.datetime(2151, 2, 7, 11, 45), 90.0),
#   (datetime.datetime(2151, 2, 7, 12, 45), nan),
#   (datetime.datetime(2151, 2, 7, 13, 45), 98.0),
#   (datetime.datetime(2151, 2, 7, 14, 45), nan),
#   (datetime.datetime(2151, 2, 7, 15, 45), 106.0),
#   (datetime.datetime(2151, 2, 7, 16, 45), 94.0),
#   (datetime.datetime(2151, 2, 7, 17, 45), 114.0),
#   (datetime.datetime(2151, 2, 7, 18, 45), 98.0),
#   (datetime.datetime(2151, 2, 7, 19, 45), 85.0),
#   (datetime.datetime(2151, 2, 7, 20, 45), 98.0),
#   (datetime.datetime(2151, 2, 7, 21, 45), nan),
#   (datetime.datetime(2151, 2, 7, 22, 45), 89.0),
#   (datetime.datetime(2151, 2, 7, 23, 45), 97.0),
#   (datetime.datetime(2151, 2, 8, 0, 45), 100.0),
#   (datetime.datetime(2151, 2, 8, 1, 45), 106.0),
#   (datetime.datetime(2151, 2, 8, 2, 45), 90.0),
#   (datetime.datetime(2151, 2, 8, 3, 45), 105.0),
#   (datetime.datetime(2151, 2, 8, 4, 45), 98.0),
#   (datetime.datetime(2151, 2, 8, 5, 45), 110.0),
#   (datetime.datetime(2151, 2, 8, 6, 45), 110.0),
#   (datetime.datetime(2151, 2, 8, 7, 45), 103.0),
#   (datetime.datetime(2151, 2, 8, 8, 45), 93.0),
#   (datetime.datetime(2151, 2, 8, 9, 45), 95.0),
#   (datetime.datetime(2151, 2, 8, 10, 45), 95.0),
#   (datetime.datetime(2151, 2, 8, 11, 45), 85.0),
#   (datetime.datetime(2151, 2, 8, 12, 45), 86.0),
#   (datetime.datetime(2151, 2, 8, 13, 45), 92.0),
#   (datetime.datetime(2151, 2, 8, 14, 45), 90.0),
#   (datetime.datetime(2151, 2, 8, 15, 45), 95.0),
#   (datetime.datetime(2151, 2, 8, 16, 45), 97.0),
#   (datetime.datetime(2151, 2, 8, 17, 45), 95.0),
#   (datetime.datetime(2151, 2, 8, 18, 45), 92.0),
#   (datetime.datetime(2151, 2, 8, 19, 45), 95.0),
#   (datetime.datetime(2151, 2, 8, 20, 45), 86.0),
#   (datetime.datetime(2151, 2, 8, 21, 45), 82.0),
#   (datetime.datetime(2151, 2, 8, 22, 45), 91.0),
#   (datetime.datetime(2151, 2, 8, 23, 45), 80.0),
#   (datetime.datetime(2151, 2, 9, 0, 45), 86.0),
#   (datetime.datetime(2151, 2, 9, 1, 45), 66.0),
#   (datetime.datetime(2151, 2, 9, 2, 45), 68.0),
#   (datetime.datetime(2151, 2, 9, 3, 45), 76.0),
#   (datetime.datetime(2151, 2, 9, 4, 45), 79.0),
#   (datetime.datetime(2151, 2, 9, 5, 45), 78.0),
#   (datetime.datetime(2151, 2, 9, 6, 45), 78.0),
#   (datetime.datetime(2151, 2, 9, 7, 45), 90.0),
#   (datetime.datetime(2151, 2, 9, 8, 45), 84.0),
#   (datetime.datetime(2151, 2, 9, 9, 45), 66.0),
#   (datetime.datetime(2151, 2, 9, 10, 45), 81.0),
#   (datetime.datetime(2151, 2, 9, 11, 45), 85.0),
#   (datetime.datetime(2151, 2, 9, 12, 45), 80.0),
#   (datetime.datetime(2151, 2, 9, 13, 45), 81.0),
#   (datetime.datetime(2151, 2, 9, 14, 45), 67.0),
#   (datetime.datetime(2151, 2, 9, 15, 45), 90.0),
#   (datetime.datetime(2151, 2, 9, 16, 45), 81.0),
#   (datetime.datetime(2151, 2, 9, 17, 45), 69.0),
#   (datetime.datetime(2151, 2, 9, 18, 45), 71.0),
#   (datetime.datetime(2151, 2, 9, 19, 45), 71.0),
#   (datetime.datetime(2151, 2, 9, 20, 45), 80.0),
#   (datetime.datetime(2151, 2, 9, 21, 45), 79.0),
#   (datetime.datetime(2151, 2, 9, 22, 45), 62.0),
#   (datetime.datetime(2151, 2, 9, 23, 45), 84.0),
#   (datetime.datetime(2151, 2, 10, 0, 45), 78.0),
#   (datetime.datetime(2151, 2, 10, 1, 45), 81.0),
#   (datetime.datetime(2151, 2, 10, 2, 45), 96.0),
#   (datetime.datetime(2151, 2, 10, 3, 45), 86.0),
#   (datetime.datetime(2151, 2, 10, 4, 45), 89.0),
#   (datetime.datetime(2151, 2, 10, 5, 45), 100.0),
#   (datetime.datetime(2151, 2, 10, 6, 45), 93.0),
#   (datetime.datetime(2151, 2, 10, 7, 45), 70.0),
#   (datetime.datetime(2151, 2, 10, 8, 45), 81.0),
#   (datetime.datetime(2151, 2, 10, 9, 45), 80.0),
#   (datetime.datetime(2151, 2, 10, 10, 45), 85.0),
#   (datetime.datetime(2151, 2, 10, 11, 45), 60.0),
#   (datetime.datetime(2151, 2, 10, 12, 45), 54.0)],
#  'RESP': [(datetime.datetime(2151, 2, 1, 8, 45), nan),
#   (datetime.datetime(2151, 2, 1, 9, 45), nan),
#   (datetime.datetime(2151, 2, 1, 10, 45), nan),
#   (datetime.datetime(2151, 2, 1, 11, 45), nan),
#   (datetime.datetime(2151, 2, 1, 12, 45), nan),
#   (datetime.datetime(2151, 2, 1, 13, 45), nan),
#   (datetime.datetime(2151, 2, 1, 14, 45), 10.0),
#   (datetime.datetime(2151, 2, 1, 15, 45), 17.0),
#   (datetime.datetime(2151, 2, 1, 16, 45), 10.0),
#   (datetime.datetime(2151, 2, 1, 17, 45), 11.0),
#   (datetime.datetime(2151, 2, 1, 18, 45), 17.0),
#   (datetime.datetime(2151, 2, 1, 19, 45), 19.0),
#   (datetime.datetime(2151, 2, 1, 20, 45), 12.0),
#   (datetime.datetime(2151, 2, 1, 21, 45), 9.0),
#   (datetime.datetime(2151, 2, 1, 22, 45), 8.0),
#   (datetime.datetime(2151, 2, 1, 23, 45), 14.0),
#   (datetime.datetime(2151, 2, 2, 0, 45), 12.0),
#   (datetime.datetime(2151, 2, 2, 1, 45), 14.0),
#   (datetime.datetime(2151, 2, 2, 2, 45), 14.0),
#   (datetime.datetime(2151, 2, 2, 3, 45), 16.0),
#   (datetime.datetime(2151, 2, 2, 4, 45), 12.0),
#   (datetime.datetime(2151, 2, 2, 5, 45), 12.0),
#   (datetime.datetime(2151, 2, 2, 6, 45), 13.0),
#   (datetime.datetime(2151, 2, 2, 7, 45), 15.0),
#   (datetime.datetime(2151, 2, 2, 8, 45), 11.0),
#   (datetime.datetime(2151, 2, 2, 9, 45), 13.0),
#   (datetime.datetime(2151, 2, 2, 10, 45), 18.0),
#   (datetime.datetime(2151, 2, 2, 11, 45), 13.0),
#   (datetime.datetime(2151, 2, 2, 12, 45), 10.0),
#   (datetime.datetime(2151, 2, 2, 13, 45), 11.0),
#   (datetime.datetime(2151, 2, 2, 14, 45), nan),
#   (datetime.datetime(2151, 2, 2, 15, 45), 14.0),
#   (datetime.datetime(2151, 2, 2, 16, 45), 15.0),
#   (datetime.datetime(2151, 2, 2, 17, 45), 14.0),
#   (datetime.datetime(2151, 2, 2, 18, 45), 6.0),
#   (datetime.datetime(2151, 2, 2, 19, 45), 11.0),
#   (datetime.datetime(2151, 2, 2, 20, 45), 12.0),
#   (datetime.datetime(2151, 2, 2, 21, 45), 9.0),
#   (datetime.datetime(2151, 2, 2, 22, 45), 17.0),
#   (datetime.datetime(2151, 2, 2, 23, 45), 17.0),
#   (datetime.datetime(2151, 2, 3, 0, 45), 11.0),
#   (datetime.datetime(2151, 2, 3, 1, 45), 15.0),
#   (datetime.datetime(2151, 2, 3, 2, 45), 15.0),
#   (datetime.datetime(2151, 2, 3, 3, 45), 12.0),
#   (datetime.datetime(2151, 2, 3, 4, 45), 18.0),
#   (datetime.datetime(2151, 2, 3, 5, 45), 17.0),
#   (datetime.datetime(2151, 2, 3, 6, 45), 24.0),
#   (datetime.datetime(2151, 2, 3, 7, 45), 33.0),
#   (datetime.datetime(2151, 2, 3, 8, 45), 17.0),
#   (datetime.datetime(2151, 2, 3, 9, 45), 27.0),
#   (datetime.datetime(2151, 2, 3, 10, 45), 23.0),
#   (datetime.datetime(2151, 2, 3, 11, 45), 27.0),
#   (datetime.datetime(2151, 2, 3, 12, 45), 27.0),
#   (datetime.datetime(2151, 2, 3, 13, 45), 20.0),
#   (datetime.datetime(2151, 2, 3, 14, 45), 32.0),
#   (datetime.datetime(2151, 2, 3, 15, 45), 22.0),
#   (datetime.datetime(2151, 2, 3, 16, 45), 17.0),
#   (datetime.datetime(2151, 2, 3, 17, 45), 47.0),
#   (datetime.datetime(2151, 2, 3, 18, 45), 28.0),
#   (datetime.datetime(2151, 2, 3, 19, 45), 24.0),
#   (datetime.datetime(2151, 2, 3, 20, 45), 22.0),
#   (datetime.datetime(2151, 2, 3, 21, 45), 22.0),
#   (datetime.datetime(2151, 2, 3, 22, 45), 24.0),
#   (datetime.datetime(2151, 2, 3, 23, 45), 24.0),
#   (datetime.datetime(2151, 2, 4, 0, 45), 26.0),
#   (datetime.datetime(2151, 2, 4, 1, 45), 26.0),
#   (datetime.datetime(2151, 2, 4, 2, 45), 26.0),
#   (datetime.datetime(2151, 2, 4, 3, 45), 26.0),
#   (datetime.datetime(2151, 2, 4, 4, 45), 28.0),
#   (datetime.datetime(2151, 2, 4, 5, 45), 26.0),
#   (datetime.datetime(2151, 2, 4, 6, 45), 38.0),
#   (datetime.datetime(2151, 2, 4, 7, 45), 22.0),
#   (datetime.datetime(2151, 2, 4, 8, 45), 21.0),
#   (datetime.datetime(2151, 2, 4, 9, 45), 28.0),
#   (datetime.datetime(2151, 2, 4, 10, 45), 23.0),
#   (datetime.datetime(2151, 2, 4, 11, 45), 18.0),
#   (datetime.datetime(2151, 2, 4, 12, 45), 20.0),
#   (datetime.datetime(2151, 2, 4, 13, 45), 27.0),
#   (datetime.datetime(2151, 2, 4, 14, 45), 26.0),
#   (datetime.datetime(2151, 2, 4, 15, 45), 22.0),
#   (datetime.datetime(2151, 2, 4, 16, 45), 24.0),
#   (datetime.datetime(2151, 2, 4, 17, 45), 24.0),
#   (datetime.datetime(2151, 2, 4, 18, 45), 26.0),
#   (datetime.datetime(2151, 2, 4, 19, 45), 20.0),
#   (datetime.datetime(2151, 2, 4, 20, 45), 24.0),
#   (datetime.datetime(2151, 2, 4, 21, 45), 14.0),
#   (datetime.datetime(2151, 2, 4, 22, 45), nan),
#   (datetime.datetime(2151, 2, 4, 23, 45), 18.0),
#   (datetime.datetime(2151, 2, 5, 0, 45), 17.0),
#   (datetime.datetime(2151, 2, 5, 1, 45), 18.0),
#   (datetime.datetime(2151, 2, 5, 2, 45), 18.0),
#   (datetime.datetime(2151, 2, 5, 3, 45), 20.0),
#   (datetime.datetime(2151, 2, 5, 4, 45), 20.0),
#   (datetime.datetime(2151, 2, 5, 5, 45), 20.0),
#   (datetime.datetime(2151, 2, 5, 6, 45), nan),
#   (datetime.datetime(2151, 2, 5, 7, 45), 20.0),
#   (datetime.datetime(2151, 2, 5, 8, 45), 24.0),
#   (datetime.datetime(2151, 2, 5, 9, 45), 17.0),
#   (datetime.datetime(2151, 2, 5, 10, 45), 30.0),
#   (datetime.datetime(2151, 2, 5, 11, 45), 23.0),
#   (datetime.datetime(2151, 2, 5, 12, 45), 26.0),
#   (datetime.datetime(2151, 2, 5, 13, 45), 29.0),
#   (datetime.datetime(2151, 2, 5, 14, 45), 24.0),
#   (datetime.datetime(2151, 2, 5, 15, 45), 30.0),
#   (datetime.datetime(2151, 2, 5, 16, 45), 24.0),
#   (datetime.datetime(2151, 2, 5, 17, 45), 30.0),
#   (datetime.datetime(2151, 2, 5, 18, 45), 27.0),
#   (datetime.datetime(2151, 2, 5, 19, 45), 29.0),
#   (datetime.datetime(2151, 2, 5, 20, 45), 29.0),
#   (datetime.datetime(2151, 2, 5, 21, 45), 30.0),
#   (datetime.datetime(2151, 2, 5, 22, 45), 28.0),
#   (datetime.datetime(2151, 2, 5, 23, 45), 33.0),
#   (datetime.datetime(2151, 2, 6, 0, 45), 32.0),
#   (datetime.datetime(2151, 2, 6, 1, 45), 28.0),
#   (datetime.datetime(2151, 2, 6, 2, 45), 26.0),
#   (datetime.datetime(2151, 2, 6, 3, 45), 24.0),
#   (datetime.datetime(2151, 2, 6, 4, 45), 24.0),
#   (datetime.datetime(2151, 2, 6, 5, 45), 39.0),
#   (datetime.datetime(2151, 2, 6, 6, 45), nan),
#   (datetime.datetime(2151, 2, 6, 7, 45), 30.0),
#   (datetime.datetime(2151, 2, 6, 8, 45), 28.0),
#   (datetime.datetime(2151, 2, 6, 9, 45), 27.0),
#   (datetime.datetime(2151, 2, 6, 10, 45), 28.0),
#   (datetime.datetime(2151, 2, 6, 11, 45), 27.0),
#   (datetime.datetime(2151, 2, 6, 12, 45), 20.0),
#   (datetime.datetime(2151, 2, 6, 13, 45), nan),
#   (datetime.datetime(2151, 2, 6, 14, 45), 22.0),
#   (datetime.datetime(2151, 2, 6, 15, 45), 28.0),
#   (datetime.datetime(2151, 2, 6, 16, 45), 26.0),
#   (datetime.datetime(2151, 2, 6, 17, 45), 18.0),
#   (datetime.datetime(2151, 2, 6, 18, 45), 17.0),
#   (datetime.datetime(2151, 2, 6, 19, 45), 26.0),
#   (datetime.datetime(2151, 2, 6, 20, 45), 18.0),
#   (datetime.datetime(2151, 2, 6, 21, 45), 23.0),
#   (datetime.datetime(2151, 2, 6, 22, 45), 16.0),
#   (datetime.datetime(2151, 2, 6, 23, 45), 18.0),
#   (datetime.datetime(2151, 2, 7, 0, 45), 27.0),
#   (datetime.datetime(2151, 2, 7, 1, 45), 30.0),
#   (datetime.datetime(2151, 2, 7, 2, 45), 21.0),
#   (datetime.datetime(2151, 2, 7, 3, 45), 21.0),
#   (datetime.datetime(2151, 2, 7, 4, 45), 22.0),
#   (datetime.datetime(2151, 2, 7, 5, 45), 17.0),
#   (datetime.datetime(2151, 2, 7, 6, 45), 17.0),
#   (datetime.datetime(2151, 2, 7, 7, 45), 22.0),
#   (datetime.datetime(2151, 2, 7, 8, 45), nan),
#   (datetime.datetime(2151, 2, 7, 9, 45), 31.0),
#   (datetime.datetime(2151, 2, 7, 10, 45), nan),
#   (datetime.datetime(2151, 2, 7, 11, 45), 22.0),
#   (datetime.datetime(2151, 2, 7, 12, 45), nan),
#   (datetime.datetime(2151, 2, 7, 13, 45), 24.0),
#   (datetime.datetime(2151, 2, 7, 14, 45), nan),
#   (datetime.datetime(2151, 2, 7, 15, 45), nan),
#   (datetime.datetime(2151, 2, 7, 16, 45), nan),
#   (datetime.datetime(2151, 2, 7, 17, 45), 24.0),
#   (datetime.datetime(2151, 2, 7, 18, 45), 29.0),
#   (datetime.datetime(2151, 2, 7, 19, 45), nan),
#   (datetime.datetime(2151, 2, 7, 20, 45), 33.0),
#   (datetime.datetime(2151, 2, 7, 21, 45), nan),
#   (datetime.datetime(2151, 2, 7, 22, 45), 30.0),
#   (datetime.datetime(2151, 2, 7, 23, 45), 23.0),
#   (datetime.datetime(2151, 2, 8, 0, 45), 27.0),
#   (datetime.datetime(2151, 2, 8, 1, 45), 13.0),
#   (datetime.datetime(2151, 2, 8, 2, 45), 21.0),
#   (datetime.datetime(2151, 2, 8, 3, 45), 24.0),
#   (datetime.datetime(2151, 2, 8, 4, 45), 28.0),
#   (datetime.datetime(2151, 2, 8, 5, 45), 19.0),
#   (datetime.datetime(2151, 2, 8, 6, 45), 19.0),
#   (datetime.datetime(2151, 2, 8, 7, 45), 28.0),
#   (datetime.datetime(2151, 2, 8, 8, 45), 34.0),
#   (datetime.datetime(2151, 2, 8, 9, 45), 28.0),
#   (datetime.datetime(2151, 2, 8, 10, 45), 29.0),
#   (datetime.datetime(2151, 2, 8, 11, 45), 33.0),
#   (datetime.datetime(2151, 2, 8, 12, 45), 28.0),
#   (datetime.datetime(2151, 2, 8, 13, 45), 29.0),
#   (datetime.datetime(2151, 2, 8, 14, 45), 32.0),
#   (datetime.datetime(2151, 2, 8, 15, 45), 46.0),
#   (datetime.datetime(2151, 2, 8, 16, 45), 31.0),
#   (datetime.datetime(2151, 2, 8, 17, 45), 30.0),
#   (datetime.datetime(2151, 2, 8, 18, 45), 29.0),
#   (datetime.datetime(2151, 2, 8, 19, 45), 24.0),
#   (datetime.datetime(2151, 2, 8, 20, 45), 28.0),
#   (datetime.datetime(2151, 2, 8, 21, 45), 20.0),
#   (datetime.datetime(2151, 2, 8, 22, 45), 28.0),
#   (datetime.datetime(2151, 2, 8, 23, 45), 29.0),
#   (datetime.datetime(2151, 2, 9, 0, 45), 28.0),
#   (datetime.datetime(2151, 2, 9, 1, 45), 28.0),
#   (datetime.datetime(2151, 2, 9, 2, 45), 28.0),
#   (datetime.datetime(2151, 2, 9, 3, 45), 24.0),
#   (datetime.datetime(2151, 2, 9, 4, 45), 31.0),
#   (datetime.datetime(2151, 2, 9, 5, 45), 38.0),
#   (datetime.datetime(2151, 2, 9, 6, 45), 34.0),
#   (datetime.datetime(2151, 2, 9, 7, 45), 30.0),
#   (datetime.datetime(2151, 2, 9, 8, 45), 30.0),
#   (datetime.datetime(2151, 2, 9, 9, 45), 30.0),
#   (datetime.datetime(2151, 2, 9, 10, 45), 29.0),
#   (datetime.datetime(2151, 2, 9, 11, 45), 28.0),
#   (datetime.datetime(2151, 2, 9, 12, 45), 30.0),
#   (datetime.datetime(2151, 2, 9, 13, 45), 28.0),
#   (datetime.datetime(2151, 2, 9, 14, 45), 44.0),
#   (datetime.datetime(2151, 2, 9, 15, 45), 60.0),
#   (datetime.datetime(2151, 2, 9, 16, 45), 25.0),
#   (datetime.datetime(2151, 2, 9, 17, 45), 55.0),
#   (datetime.datetime(2151, 2, 9, 18, 45), 50.0),
#   (datetime.datetime(2151, 2, 9, 19, 45), 71.0),
#   (datetime.datetime(2151, 2, 9, 20, 45), 42.0),
#   (datetime.datetime(2151, 2, 9, 21, 45), 37.0),
#   (datetime.datetime(2151, 2, 9, 22, 45), 47.0),
#   (datetime.datetime(2151, 2, 9, 23, 45), 33.0),
#   (datetime.datetime(2151, 2, 10, 0, 45), 38.0),
#   (datetime.datetime(2151, 2, 10, 1, 45), 32.0),
#   (datetime.datetime(2151, 2, 10, 2, 45), 30.0),
#   (datetime.datetime(2151, 2, 10, 3, 45), 32.0),
#   (datetime.datetime(2151, 2, 10, 4, 45), 37.0),
#   (datetime.datetime(2151, 2, 10, 5, 45), 24.0),
#   (datetime.datetime(2151, 2, 10, 6, 45), 29.0),
#   (datetime.datetime(2151, 2, 10, 7, 45), 26.0),
#   (datetime.datetime(2151, 2, 10, 8, 45), 30.0),
#   (datetime.datetime(2151, 2, 10, 9, 45), 28.0),
#   (datetime.datetime(2151, 2, 10, 10, 45), 32.0),
#   (datetime.datetime(2151, 2, 10, 11, 45), 26.0),
#   (datetime.datetime(2151, 2, 10, 12, 45), 26.0)],
#  'SBP': [(datetime.datetime(2151, 2, 1, 8, 45), nan),
#   (datetime.datetime(2151, 2, 1, 9, 45), nan),
#   (datetime.datetime(2151, 2, 1, 10, 45), nan),
#   (datetime.datetime(2151, 2, 1, 11, 45), nan),
#   (datetime.datetime(2151, 2, 1, 12, 45), nan),
#   (datetime.datetime(2151, 2, 1, 13, 45), nan),
#   (datetime.datetime(2151, 2, 1, 14, 45), 154.0),
#   (datetime.datetime(2151, 2, 1, 15, 45), 150.0),
#   (datetime.datetime(2151, 2, 1, 16, 45), 150.0),
#   (datetime.datetime(2151, 2, 1, 17, 45), 148.0),
#   (datetime.datetime(2151, 2, 1, 18, 45), 130.0),
#   (datetime.datetime(2151, 2, 1, 19, 45), 143.0),
#   (datetime.datetime(2151, 2, 1, 20, 45), 130.0),
#   (datetime.datetime(2151, 2, 1, 21, 45), 134.0),
#   (datetime.datetime(2151, 2, 1, 22, 45), 112.0),
#   (datetime.datetime(2151, 2, 1, 23, 45), 117.0),
#   (datetime.datetime(2151, 2, 2, 0, 45), 113.0),
#   (datetime.datetime(2151, 2, 2, 1, 45), 116.0),
#   (datetime.datetime(2151, 2, 2, 2, 45), 105.0),
#   (datetime.datetime(2151, 2, 2, 3, 45), 106.0),
#   (datetime.datetime(2151, 2, 2, 4, 45), 103.0),
#   (datetime.datetime(2151, 2, 2, 5, 45), 109.0),
#   (datetime.datetime(2151, 2, 2, 6, 45), 101.0),
#   (datetime.datetime(2151, 2, 2, 7, 45), 107.0),
#   (datetime.datetime(2151, 2, 2, 8, 45), 102.0),
#   (datetime.datetime(2151, 2, 2, 9, 45), 106.0),
#   (datetime.datetime(2151, 2, 2, 10, 45), 106.0),
#   (datetime.datetime(2151, 2, 2, 11, 45), 110.0),
#   (datetime.datetime(2151, 2, 2, 12, 45), 100.0),
#   (datetime.datetime(2151, 2, 2, 13, 45), 83.0),
#   (datetime.datetime(2151, 2, 2, 14, 45), nan),
#   (datetime.datetime(2151, 2, 2, 15, 45), 108.0),
#   (datetime.datetime(2151, 2, 2, 16, 45), 110.0),
#   (datetime.datetime(2151, 2, 2, 17, 45), 101.0),
#   (datetime.datetime(2151, 2, 2, 18, 45), 98.0),
#   (datetime.datetime(2151, 2, 2, 19, 45), 115.0),
#   (datetime.datetime(2151, 2, 2, 20, 45), 101.0),
#   (datetime.datetime(2151, 2, 2, 21, 45), 111.0),
#   (datetime.datetime(2151, 2, 2, 22, 45), 122.0),
#   (datetime.datetime(2151, 2, 2, 23, 45), 115.0),
#   (datetime.datetime(2151, 2, 3, 0, 45), 126.0),
#   (datetime.datetime(2151, 2, 3, 1, 45), 118.0),
#   (datetime.datetime(2151, 2, 3, 2, 45), 120.0),
#   (datetime.datetime(2151, 2, 3, 3, 45), 131.0),
#   (datetime.datetime(2151, 2, 3, 4, 45), 136.0),
#   (datetime.datetime(2151, 2, 3, 5, 45), 125.0),
#   (datetime.datetime(2151, 2, 3, 6, 45), 103.0),
#   (datetime.datetime(2151, 2, 3, 7, 45), 118.0),
#   (datetime.datetime(2151, 2, 3, 8, 45), 111.0),
#   (datetime.datetime(2151, 2, 3, 9, 45), 120.0),
#   (datetime.datetime(2151, 2, 3, 10, 45), 134.0),
#   (datetime.datetime(2151, 2, 3, 11, 45), 120.0),
#   (datetime.datetime(2151, 2, 3, 12, 45), 127.0),
#   (datetime.datetime(2151, 2, 3, 13, 45), 142.0),
#   (datetime.datetime(2151, 2, 3, 14, 45), 125.0),
#   (datetime.datetime(2151, 2, 3, 15, 45), 133.0),
#   (datetime.datetime(2151, 2, 3, 16, 45), 126.0),
#   (datetime.datetime(2151, 2, 3, 17, 45), 119.0),
#   (datetime.datetime(2151, 2, 3, 18, 45), 133.0),
#   (datetime.datetime(2151, 2, 3, 19, 45), 111.0),
#   (datetime.datetime(2151, 2, 3, 20, 45), 125.0),
#   (datetime.datetime(2151, 2, 3, 21, 45), 124.0),
#   (datetime.datetime(2151, 2, 3, 22, 45), 128.0),
#   (datetime.datetime(2151, 2, 3, 23, 45), 133.0),
#   (datetime.datetime(2151, 2, 4, 0, 45), 147.0),
#   (datetime.datetime(2151, 2, 4, 1, 45), 126.0),
#   (datetime.datetime(2151, 2, 4, 2, 45), 121.0),
#   (datetime.datetime(2151, 2, 4, 3, 45), 143.0),
#   (datetime.datetime(2151, 2, 4, 4, 45), 132.0),
#   (datetime.datetime(2151, 2, 4, 5, 45), 124.0),
#   (datetime.datetime(2151, 2, 4, 6, 45), 130.0),
#   (datetime.datetime(2151, 2, 4, 7, 45), 140.0),
#   (datetime.datetime(2151, 2, 4, 8, 45), 135.0),
#   (datetime.datetime(2151, 2, 4, 9, 45), 151.0),
#   (datetime.datetime(2151, 2, 4, 10, 45), 150.0),
#   (datetime.datetime(2151, 2, 4, 11, 45), 135.0),
#   (datetime.datetime(2151, 2, 4, 12, 45), 117.0),
#   (datetime.datetime(2151, 2, 4, 13, 45), 149.0),
#   (datetime.datetime(2151, 2, 4, 14, 45), 154.0),
#   (datetime.datetime(2151, 2, 4, 15, 45), 147.0),
#   (datetime.datetime(2151, 2, 4, 16, 45), 117.0),
#   (datetime.datetime(2151, 2, 4, 17, 45), 162.0),
#   (datetime.datetime(2151, 2, 4, 18, 45), 156.0),
#   (datetime.datetime(2151, 2, 4, 19, 45), 160.0),
#   (datetime.datetime(2151, 2, 4, 20, 45), 161.0),
#   (datetime.datetime(2151, 2, 4, 21, 45), 159.0),
#   (datetime.datetime(2151, 2, 4, 22, 45), nan),
#   (datetime.datetime(2151, 2, 4, 23, 45), 107.0),
#   (datetime.datetime(2151, 2, 5, 0, 45), 116.0),
#   (datetime.datetime(2151, 2, 5, 1, 45), 127.0),
#   (datetime.datetime(2151, 2, 5, 2, 45), 123.0),
#   (datetime.datetime(2151, 2, 5, 3, 45), 133.0),
#   (datetime.datetime(2151, 2, 5, 4, 45), 114.0),
#   (datetime.datetime(2151, 2, 5, 5, 45), 143.0),
#   (datetime.datetime(2151, 2, 5, 6, 45), nan),
#   (datetime.datetime(2151, 2, 5, 7, 45), 129.0),
#   (datetime.datetime(2151, 2, 5, 8, 45), 119.0),
#   (datetime.datetime(2151, 2, 5, 9, 45), 137.0),
#   (datetime.datetime(2151, 2, 5, 10, 45), 133.0),
#   (datetime.datetime(2151, 2, 5, 11, 45), 134.0),
#   (datetime.datetime(2151, 2, 5, 12, 45), 135.0),
#   (datetime.datetime(2151, 2, 5, 13, 45), 134.0),
#   (datetime.datetime(2151, 2, 5, 14, 45), 131.0),
#   (datetime.datetime(2151, 2, 5, 15, 45), 127.0),
#   (datetime.datetime(2151, 2, 5, 16, 45), 132.0),
#   (datetime.datetime(2151, 2, 5, 17, 45), 125.0),
#   (datetime.datetime(2151, 2, 5, 18, 45), 98.0),
#   (datetime.datetime(2151, 2, 5, 19, 45), 114.0),
#   (datetime.datetime(2151, 2, 5, 20, 45), 147.0),
#   (datetime.datetime(2151, 2, 5, 21, 45), 144.0),
#   (datetime.datetime(2151, 2, 5, 22, 45), 154.0),
#   (datetime.datetime(2151, 2, 5, 23, 45), 133.0),
#   (datetime.datetime(2151, 2, 6, 0, 45), 135.0),
#   (datetime.datetime(2151, 2, 6, 1, 45), 133.0),
#   (datetime.datetime(2151, 2, 6, 2, 45), 137.0),
#   (datetime.datetime(2151, 2, 6, 3, 45), 133.0),
#   (datetime.datetime(2151, 2, 6, 4, 45), 138.0),
#   (datetime.datetime(2151, 2, 6, 5, 45), 148.0),
#   (datetime.datetime(2151, 2, 6, 6, 45), nan),
#   (datetime.datetime(2151, 2, 6, 7, 45), 150.0),
#   (datetime.datetime(2151, 2, 6, 8, 45), 137.0),
#   (datetime.datetime(2151, 2, 6, 9, 45), 149.0),
#   (datetime.datetime(2151, 2, 6, 10, 45), 141.0),
#   (datetime.datetime(2151, 2, 6, 11, 45), 143.0),
#   (datetime.datetime(2151, 2, 6, 12, 45), 142.0),
#   (datetime.datetime(2151, 2, 6, 13, 45), nan),
#   (datetime.datetime(2151, 2, 6, 14, 45), 148.0),
#   (datetime.datetime(2151, 2, 6, 15, 45), 150.0),
#   (datetime.datetime(2151, 2, 6, 16, 45), 147.0),
#   (datetime.datetime(2151, 2, 6, 17, 45), 143.0),
#   (datetime.datetime(2151, 2, 6, 18, 45), 138.0),
#   (datetime.datetime(2151, 2, 6, 19, 45), 147.0),
#   (datetime.datetime(2151, 2, 6, 20, 45), 138.0),
#   (datetime.datetime(2151, 2, 6, 21, 45), 130.0),
#   (datetime.datetime(2151, 2, 6, 22, 45), 140.0),
#   (datetime.datetime(2151, 2, 6, 23, 45), 162.0),
#   (datetime.datetime(2151, 2, 7, 0, 45), 152.0),
#   (datetime.datetime(2151, 2, 7, 1, 45), 127.0),
#   (datetime.datetime(2151, 2, 7, 2, 45), 153.0),
#   (datetime.datetime(2151, 2, 7, 3, 45), 152.0),
#   (datetime.datetime(2151, 2, 7, 4, 45), 137.0),
#   (datetime.datetime(2151, 2, 7, 5, 45), 164.0),
#   (datetime.datetime(2151, 2, 7, 6, 45), 155.0),
#   (datetime.datetime(2151, 2, 7, 7, 45), 142.0),
#   (datetime.datetime(2151, 2, 7, 8, 45), nan),
#   (datetime.datetime(2151, 2, 7, 9, 45), 133.0),
#   (datetime.datetime(2151, 2, 7, 10, 45), nan),
#   (datetime.datetime(2151, 2, 7, 11, 45), 148.0),
#   (datetime.datetime(2151, 2, 7, 12, 45), nan),
#   (datetime.datetime(2151, 2, 7, 13, 45), 155.0),
#   (datetime.datetime(2151, 2, 7, 14, 45), nan),
#   (datetime.datetime(2151, 2, 7, 15, 45), 162.0),
#   (datetime.datetime(2151, 2, 7, 16, 45), 147.0),
#   (datetime.datetime(2151, 2, 7, 17, 45), 154.0),
#   (datetime.datetime(2151, 2, 7, 18, 45), 150.0),
#   (datetime.datetime(2151, 2, 7, 19, 45), 137.0),
#   (datetime.datetime(2151, 2, 7, 20, 45), 166.0),
#   (datetime.datetime(2151, 2, 7, 21, 45), nan),
#   (datetime.datetime(2151, 2, 7, 22, 45), 160.0),
#   (datetime.datetime(2151, 2, 7, 23, 45), 156.0),
#   (datetime.datetime(2151, 2, 10, 0, 45), 156.0),
#   (datetime.datetime(2151, 2, 10, 1, 45), 167.0),
#   (datetime.datetime(2151, 2, 10, 2, 45), 172.0),
#   (datetime.datetime(2151, 2, 10, 3, 45), 174.0),
#   (datetime.datetime(2151, 2, 10, 4, 45), 171.0),
#   (datetime.datetime(2151, 2, 10, 5, 45), 174.0),
#   (datetime.datetime(2151, 2, 10, 6, 45), 173.0),
#   (datetime.datetime(2151, 2, 10, 7, 45), 164.0),
#   (datetime.datetime(2151, 2, 10, 8, 45), 156.0),
#   (datetime.datetime(2151, 2, 10, 9, 45), 137.0),
#   (datetime.datetime(2151, 2, 10, 10, 45), 138.0),
#   (datetime.datetime(2151, 2, 10, 11, 45), 127.0),
#   (datetime.datetime(2151, 2, 10, 12, 45), 117.0)],
#  'DBP': [(datetime.datetime(2151, 2, 1, 8, 45), nan),
#   (datetime.datetime(2151, 2, 1, 9, 45), nan),
#   (datetime.datetime(2151, 2, 1, 10, 45), nan),
#   (datetime.datetime(2151, 2, 1, 11, 45), nan),
#   (datetime.datetime(2151, 2, 1, 12, 45), nan),
#   (datetime.datetime(2151, 2, 1, 13, 45), nan),
#   (datetime.datetime(2151, 2, 1, 14, 45), 85.0),
#   (datetime.datetime(2151, 2, 1, 15, 45), 86.0),
#   (datetime.datetime(2151, 2, 1, 16, 45), 84.0),
#   (datetime.datetime(2151, 2, 1, 17, 45), 81.0),
#   (datetime.datetime(2151, 2, 1, 18, 45), 75.0),
#   (datetime.datetime(2151, 2, 1, 19, 45), 79.0),
#   (datetime.datetime(2151, 2, 1, 20, 45), 77.0),
#   (datetime.datetime(2151, 2, 1, 21, 45), 78.0),
#   (datetime.datetime(2151, 2, 1, 22, 45), 67.0),
#   (datetime.datetime(2151, 2, 1, 23, 45), 65.0),
#   (datetime.datetime(2151, 2, 2, 0, 45), 68.0),
#   (datetime.datetime(2151, 2, 2, 1, 45), 66.0),
#   (datetime.datetime(2151, 2, 2, 2, 45), 60.0),
#   (datetime.datetime(2151, 2, 2, 3, 45), 59.0),
#   (datetime.datetime(2151, 2, 2, 4, 45), 61.0),
#   (datetime.datetime(2151, 2, 2, 5, 45), 60.0),
#   (datetime.datetime(2151, 2, 2, 6, 45), 57.0),
#   (datetime.datetime(2151, 2, 2, 7, 45), 65.0),
#   (datetime.datetime(2151, 2, 2, 8, 45), 60.0),
#   (datetime.datetime(2151, 2, 2, 9, 45), 57.0),
#   (datetime.datetime(2151, 2, 2, 10, 45), 59.0),
#   (datetime.datetime(2151, 2, 2, 11, 45), 59.0),
#   (datetime.datetime(2151, 2, 2, 12, 45), 52.0),
#   (datetime.datetime(2151, 2, 2, 13, 45), 48.0),
#   (datetime.datetime(2151, 2, 2, 14, 45), nan),
#   (datetime.datetime(2151, 2, 2, 15, 45), 54.0),
#   (datetime.datetime(2151, 2, 2, 16, 45), 59.0),
#   (datetime.datetime(2151, 2, 2, 17, 45), 47.0),
#   (datetime.datetime(2151, 2, 2, 18, 45), 51.0),
#   (datetime.datetime(2151, 2, 2, 19, 45), 58.0),
#   (datetime.datetime(2151, 2, 2, 20, 45), 51.0),
#   (datetime.datetime(2151, 2, 2, 21, 45), 55.0),
#   (datetime.datetime(2151, 2, 2, 22, 45), 63.0),
#   (datetime.datetime(2151, 2, 2, 23, 45), 59.0),
#   (datetime.datetime(2151, 2, 3, 0, 45), 57.0),
#   (datetime.datetime(2151, 2, 3, 1, 45), 57.0),
#   (datetime.datetime(2151, 2, 3, 2, 45), 57.0),
#   (datetime.datetime(2151, 2, 3, 3, 45), 63.0),
#   (datetime.datetime(2151, 2, 3, 4, 45), 66.0),
#   (datetime.datetime(2151, 2, 3, 5, 45), 54.0),
#   (datetime.datetime(2151, 2, 3, 6, 45), 48.0),
#   (datetime.datetime(2151, 2, 3, 7, 45), 55.0),
#   (datetime.datetime(2151, 2, 3, 8, 45), 55.0),
#   (datetime.datetime(2151, 2, 3, 9, 45), 56.0),
#   (datetime.datetime(2151, 2, 3, 10, 45), 61.0),
#   (datetime.datetime(2151, 2, 3, 11, 45), 56.0),
#   (datetime.datetime(2151, 2, 3, 12, 45), 69.0),
#   (datetime.datetime(2151, 2, 3, 13, 45), 72.0),
#   (datetime.datetime(2151, 2, 3, 14, 45), 60.0),
#   (datetime.datetime(2151, 2, 3, 15, 45), 68.0),
#   (datetime.datetime(2151, 2, 3, 16, 45), 63.0),
#   (datetime.datetime(2151, 2, 3, 17, 45), 56.0),
#   (datetime.datetime(2151, 2, 3, 18, 45), 64.0),
#   (datetime.datetime(2151, 2, 3, 19, 45), 54.0),
#   (datetime.datetime(2151, 2, 3, 20, 45), 53.0),
#   (datetime.datetime(2151, 2, 3, 21, 45), 63.0),
#   (datetime.datetime(2151, 2, 3, 22, 45), 81.0),
#   (datetime.datetime(2151, 2, 3, 23, 45), 46.0),
#   (datetime.datetime(2151, 2, 4, 0, 45), 49.0),
#   (datetime.datetime(2151, 2, 4, 1, 45), 35.0),
#   (datetime.datetime(2151, 2, 4, 2, 45), 51.0),
#   (datetime.datetime(2151, 2, 4, 3, 45), 55.0),
#   (datetime.datetime(2151, 2, 4, 4, 45), 48.0),
#   (datetime.datetime(2151, 2, 4, 5, 45), 41.0),
#   (datetime.datetime(2151, 2, 4, 6, 45), 79.0),
#   (datetime.datetime(2151, 2, 4, 7, 45), 71.0),
#   (datetime.datetime(2151, 2, 4, 8, 45), 78.0),
#   (datetime.datetime(2151, 2, 4, 9, 45), 79.0),
#   (datetime.datetime(2151, 2, 4, 10, 45), 60.0),
#   (datetime.datetime(2151, 2, 4, 11, 45), 86.0),
#   (datetime.datetime(2151, 2, 4, 12, 45), 48.0),
#   (datetime.datetime(2151, 2, 4, 13, 45), 72.0),
#   (datetime.datetime(2151, 2, 4, 14, 45), 76.0),
#   (datetime.datetime(2151, 2, 4, 15, 45), 59.0),
#   (datetime.datetime(2151, 2, 4, 16, 45), 47.0),
#   (datetime.datetime(2151, 2, 4, 17, 45), 66.0),
#   (datetime.datetime(2151, 2, 4, 18, 45), 74.0),
#   (datetime.datetime(2151, 2, 4, 19, 45), 79.0),
#   (datetime.datetime(2151, 2, 4, 20, 45), 80.0),
#   (datetime.datetime(2151, 2, 4, 21, 45), 79.0),
#   (datetime.datetime(2151, 2, 4, 22, 45), nan),
#   (datetime.datetime(2151, 2, 4, 23, 45), 53.0),
#   (datetime.datetime(2151, 2, 5, 0, 45), 56.0),
#   (datetime.datetime(2151, 2, 5, 1, 45), 60.0),
#   (datetime.datetime(2151, 2, 5, 2, 45), 55.0),
#   (datetime.datetime(2151, 2, 5, 3, 45), 59.0),
#   (datetime.datetime(2151, 2, 5, 4, 45), 48.0),
#   (datetime.datetime(2151, 2, 5, 5, 45), 75.0),
#   (datetime.datetime(2151, 2, 5, 6, 45), nan),
#   (datetime.datetime(2151, 2, 5, 7, 45), 57.0),
#   (datetime.datetime(2151, 2, 5, 8, 45), 52.0),
#   (datetime.datetime(2151, 2, 5, 9, 45), 71.0),
#   (datetime.datetime(2151, 2, 5, 10, 45), 67.0),
#   (datetime.datetime(2151, 2, 5, 11, 45), 76.0),
#   (datetime.datetime(2151, 2, 5, 12, 45), 70.0),
#   (datetime.datetime(2151, 2, 5, 13, 45), 70.0),
#   (datetime.datetime(2151, 2, 5, 14, 45), 64.0),
#   (datetime.datetime(2151, 2, 5, 15, 45), 64.0),
#   (datetime.datetime(2151, 2, 5, 16, 45), 65.0),
#   (datetime.datetime(2151, 2, 5, 17, 45), 64.0),
#   (datetime.datetime(2151, 2, 5, 18, 45), 39.0),
#   (datetime.datetime(2151, 2, 5, 19, 45), 50.0),
#   (datetime.datetime(2151, 2, 5, 20, 45), 80.0),
#   (datetime.datetime(2151, 2, 5, 21, 45), 78.0),
#   (datetime.datetime(2151, 2, 5, 22, 45), 81.0),
#   (datetime.datetime(2151, 2, 5, 23, 45), 72.0),
#   (datetime.datetime(2151, 2, 6, 0, 45), 78.0),
#   (datetime.datetime(2151, 2, 6, 1, 45), 72.0),
#   (datetime.datetime(2151, 2, 6, 2, 45), 76.0),
#   (datetime.datetime(2151, 2, 6, 3, 45), 69.0),
#   (datetime.datetime(2151, 2, 6, 4, 45), 74.0),
#   (datetime.datetime(2151, 2, 6, 5, 45), 79.0),
#   (datetime.datetime(2151, 2, 6, 6, 45), nan),
#   (datetime.datetime(2151, 2, 6, 7, 45), 83.0),
#   (datetime.datetime(2151, 2, 6, 8, 45), 71.0),
#   (datetime.datetime(2151, 2, 6, 9, 45), 82.0),
#   (datetime.datetime(2151, 2, 6, 10, 45), 73.0),
#   (datetime.datetime(2151, 2, 6, 11, 45), 74.0),
#   (datetime.datetime(2151, 2, 6, 12, 45), 76.0),
#   (datetime.datetime(2151, 2, 6, 13, 45), nan),
#   (datetime.datetime(2151, 2, 6, 14, 45), 79.0),
#   (datetime.datetime(2151, 2, 6, 15, 45), 77.0),
#   (datetime.datetime(2151, 2, 6, 16, 45), 80.0),
#   (datetime.datetime(2151, 2, 6, 17, 45), 63.0),
#   (datetime.datetime(2151, 2, 6, 18, 45), 66.0),
#   (datetime.datetime(2151, 2, 6, 19, 45), 75.0),
#   (datetime.datetime(2151, 2, 6, 20, 45), 66.0),
#   (datetime.datetime(2151, 2, 6, 21, 45), 64.0),
#   (datetime.datetime(2151, 2, 6, 22, 45), 61.0),
#   (datetime.datetime(2151, 2, 6, 23, 45), 80.0),
#   (datetime.datetime(2151, 2, 7, 0, 45), 67.0),
#   (datetime.datetime(2151, 2, 7, 1, 45), 48.0),
#   (datetime.datetime(2151, 2, 7, 2, 45), 62.0),
#   (datetime.datetime(2151, 2, 7, 3, 45), 69.0),
#   (datetime.datetime(2151, 2, 7, 4, 45), 59.0),
#   (datetime.datetime(2151, 2, 7, 5, 45), 74.0),
#   (datetime.datetime(2151, 2, 7, 6, 45), 74.0),
#   (datetime.datetime(2151, 2, 7, 7, 45), 73.0),
#   (datetime.datetime(2151, 2, 7, 8, 45), nan),
#   (datetime.datetime(2151, 2, 7, 9, 45), 74.0),
#   (datetime.datetime(2151, 2, 7, 10, 45), nan),
#   (datetime.datetime(2151, 2, 7, 11, 45), 44.0),
#   (datetime.datetime(2151, 2, 7, 12, 45), nan),
#   (datetime.datetime(2151, 2, 7, 13, 45), 80.0),
#   (datetime.datetime(2151, 2, 7, 14, 45), nan),
#   (datetime.datetime(2151, 2, 7, 15, 45), 87.0),
#   (datetime.datetime(2151, 2, 7, 16, 45), 74.0),
#   (datetime.datetime(2151, 2, 7, 17, 45), 87.0),
#   (datetime.datetime(2151, 2, 7, 18, 45), 72.0),
#   (datetime.datetime(2151, 2, 7, 19, 45), 65.0),
#   (datetime.datetime(2151, 2, 7, 20, 45), 83.0),
#   (datetime.datetime(2151, 2, 7, 21, 45), nan),
#   (datetime.datetime(2151, 2, 7, 22, 45), 74.0),
#   (datetime.datetime(2151, 2, 7, 23, 45), 71.0),
#   (datetime.datetime(2151, 2, 8, 0, 45), 74.0),
#   (datetime.datetime(2151, 2, 8, 1, 45), 73.0),
#   (datetime.datetime(2151, 2, 8, 2, 45), 62.0),
#   (datetime.datetime(2151, 2, 8, 3, 45), 71.0),
#   (datetime.datetime(2151, 2, 8, 4, 45), 65.0),
#   (datetime.datetime(2151, 2, 8, 5, 45), 69.0),
#   (datetime.datetime(2151, 2, 8, 6, 45), 66.0),
#   (datetime.datetime(2151, 2, 8, 7, 45), 64.0),
#   (datetime.datetime(2151, 2, 8, 8, 45), 65.0),
#   (datetime.datetime(2151, 2, 8, 9, 45), 63.0),
#   (datetime.datetime(2151, 2, 8, 10, 45), 62.0),
#   (datetime.datetime(2151, 2, 8, 11, 45), 69.0),
#   (datetime.datetime(2151, 2, 8, 12, 45), 71.0),
#   (datetime.datetime(2151, 2, 8, 13, 45), 72.0),
#   (datetime.datetime(2151, 2, 8, 14, 45), 70.0),
#   (datetime.datetime(2151, 2, 8, 15, 45), 75.0),
#   (datetime.datetime(2151, 2, 8, 16, 45), 76.0),
#   (datetime.datetime(2151, 2, 8, 17, 45), 68.0),
#   (datetime.datetime(2151, 2, 8, 18, 45), 68.0),
#   (datetime.datetime(2151, 2, 8, 19, 45), 72.0),
#   (datetime.datetime(2151, 2, 8, 20, 45), 67.0),
#   (datetime.datetime(2151, 2, 8, 21, 45), 63.0),
#   (datetime.datetime(2151, 2, 8, 22, 45), 71.0),
#   (datetime.datetime(2151, 2, 8, 23, 45), 70.0),
#   (datetime.datetime(2151, 2, 9, 0, 45), 69.0),
#   (datetime.datetime(2151, 2, 9, 1, 45), 61.0),
#   (datetime.datetime(2151, 2, 9, 2, 45), 69.0),
#   (datetime.datetime(2151, 2, 9, 3, 45), 65.0),
#   (datetime.datetime(2151, 2, 9, 4, 45), 65.0),
#   (datetime.datetime(2151, 2, 9, 5, 45), 71.0),
#   (datetime.datetime(2151, 2, 9, 6, 45), 72.0),
#   (datetime.datetime(2151, 2, 9, 7, 45), 73.0),
#   (datetime.datetime(2151, 2, 9, 8, 45), 67.0),
#   (datetime.datetime(2151, 2, 9, 9, 45), 63.0),
#   (datetime.datetime(2151, 2, 9, 10, 45), 66.0),
#   (datetime.datetime(2151, 2, 9, 11, 45), 69.0),
#   (datetime.datetime(2151, 2, 9, 12, 45), 76.0),
#   (datetime.datetime(2151, 2, 9, 13, 45), 94.0),
#   (datetime.datetime(2151, 2, 9, 14, 45), 67.0),
#   (datetime.datetime(2151, 2, 9, 15, 45), 75.0),
#   (datetime.datetime(2151, 2, 9, 16, 45), 75.0),
#   (datetime.datetime(2151, 2, 9, 17, 45), 62.0),
#   (datetime.datetime(2151, 2, 9, 18, 45), 65.0),
#   (datetime.datetime(2151, 2, 9, 19, 45), 64.0),
#   (datetime.datetime(2151, 2, 9, 20, 45), 66.0),
#   (datetime.datetime(2151, 2, 9, 21, 45), 66.0),
#   (datetime.datetime(2151, 2, 9, 22, 45), 61.0),
#   (datetime.datetime(2151, 2, 9, 23, 45), 71.0),
#   (datetime.datetime(2151, 2, 10, 0, 45), 75.0),
#   (datetime.datetime(2151, 2, 10, 1, 45), 75.0),
#   (datetime.datetime(2151, 2, 10, 2, 45), 81.0),
#   (datetime.datetime(2151, 2, 10, 3, 45), 73.0),
#   (datetime.datetime(2151, 2, 10, 4, 45), 78.0),
#   (datetime.datetime(2151, 2, 10, 5, 45), 79.0),
#   (datetime.datetime(2151, 2, 10, 6, 45), 76.0),
#   (datetime.datetime(2151, 2, 10, 7, 45), 65.0),
#   (datetime.datetime(2151, 2, 10, 8, 45), 63.0),
#   (datetime.datetime(2151, 2, 10, 9, 45), 59.0),
#   (datetime.datetime(2151, 2, 10, 10, 45), 77.0),
#   (datetime.datetime(2151, 2, 10, 11, 45), 60.0),
#   (datetime.datetime(2151, 2, 10, 12, 45), 54.0)],
#  'FiO2': [(datetime.datetime(2151, 2, 1, 8, 45), nan),
#   (datetime.datetime(2151, 2, 1, 9, 45), nan),
#   (datetime.datetime(2151, 2, 1, 10, 45), nan),
#   (datetime.datetime(2151, 2, 1, 11, 45), nan),
#   (datetime.datetime(2151, 2, 1, 12, 45), nan),
#   (datetime.datetime(2151, 2, 1, 13, 45), nan),
#   (datetime.datetime(2151, 2, 9, 13, 45), nan),
#   (datetime.datetime(2151, 2, 9, 14, 45), nan),
#   (datetime.datetime(2151, 2, 9, 15, 45), nan),
#   (datetime.datetime(2151, 2, 9, 16, 45), nan),
#   (datetime.datetime(2151, 2, 9, 17, 45), nan),
#   (datetime.datetime(2151, 2, 9, 18, 45), nan),
#   (datetime.datetime(2151, 2, 9, 19, 45), nan),
#   (datetime.datetime(2151, 2, 9, 20, 45), nan),
#   (datetime.datetime(2151, 2, 9, 21, 45), nan),
#   (datetime.datetime(2151, 2, 9, 22, 45), nan),
#   (datetime.datetime(2151, 2, 9, 23, 45), nan),
#   (datetime.datetime(2151, 2, 10, 0, 45), nan),
#   (datetime.datetime(2151, 2, 10, 1, 45), nan),
#   (datetime.datetime(2151, 2, 10, 2, 45), 31.4),
#   (datetime.datetime(2151, 2, 10, 3, 45), nan),
#   (datetime.datetime(2151, 2, 10, 4, 45), nan),
#   (datetime.datetime(2151, 2, 10, 5, 45), nan),
#   (datetime.datetime(2151, 2, 10, 6, 45), nan),
#   (datetime.datetime(2151, 2, 10, 7, 45), nan),
#   (datetime.datetime(2151, 2, 10, 8, 45), nan),
#   (datetime.datetime(2151, 2, 10, 9, 45), nan),
#   (datetime.datetime(2151, 2, 10, 10, 45), nan),
#   (datetime.datetime(2151, 2, 10, 11, 45), nan),
#   (datetime.datetime(2151, 2, 10, 12, 45), nan)]}

# %%
# Normalize for feature values
hadm_input_norm = dict()
for hadm_id in hadm_input:
  features = hadm_input[hadm_id]  
  normalized_fs = dict()
  for kk in features:
    min, max = feature_range[kk]
    vs = features[kk]
    norm_vs = list()
    for tt, vv in vs:
      if vv != np.nan:
        norm_vs.append((tt, (vv - min) / (max - min)))
      else:
        norm_vs.append(tt, np.nan)
    normalized_fs[kk] = norm_vs

  hadm_input_norm[hadm_id] = normalized_fs

# %%
hadm_input_norm
# Out:
# {160169: {'PULSE': [(datetime.datetime(2151, 2, 1, 8, 45), nan),
#    (datetime.datetime(2151, 2, 1, 9, 45), nan),
#    (datetime.datetime(2151, 2, 1, 10, 45), nan),
#    (datetime.datetime(2151, 2, 1, 11, 45), nan),
#    (datetime.datetime(2151, 2, 1, 12, 45), nan),
#    (datetime.datetime(2151, 2, 1, 13, 45), nan),
#    (datetime.datetime(2151, 2, 1, 14, 45), 0.9628378378378378),
#    (datetime.datetime(2151, 2, 1, 15, 45), 0.652027027027027),
#    (datetime.datetime(2151, 2, 1, 16, 45), 0.5912162162162162),
#    (datetime.datetime(2151, 2, 1, 17, 45), 0.5506756756756757),
#    (datetime.datetime(2151, 2, 1, 18, 45), 0.6385135135135135),
#    (datetime.datetime(2151, 2, 1, 19, 45), 0.6790540540540541),
#    (datetime.datetime(2151, 2, 1, 20, 45), 0.5912162162162162),
#    (datetime.datetime(2151, 2, 1, 21, 45), 0.5304054054054054),
#    (datetime.datetime(2151, 2, 1, 22, 45), 0.4966216216216216),
#    (datetime.datetime(2151, 2, 1, 23, 45), 0.5033783783783784),
#    (datetime.datetime(2151, 2, 9, 0, 45), nan),
#    (datetime.datetime(2151, 2, 9, 1, 45), nan),
#    (datetime.datetime(2151, 2, 9, 2, 45), 0.44184982688189484),
#    (datetime.datetime(2151, 2, 9, 3, 45), nan),
#    (datetime.datetime(2151, 2, 9, 4, 45), nan),
#    (datetime.datetime(2151, 2, 9, 5, 45), nan),
#    (datetime.datetime(2151, 2, 9, 6, 45), nan),
#    (datetime.datetime(2151, 2, 9, 7, 45), nan),
#    (datetime.datetime(2151, 2, 9, 8, 45), nan),
#    (datetime.datetime(2151, 2, 9, 9, 45), nan),
#    (datetime.datetime(2151, 2, 9, 10, 45), nan),
#    (datetime.datetime(2151, 2, 9, 11, 45), nan),
#    (datetime.datetime(2151, 2, 9, 12, 45), nan),
#    (datetime.datetime(2151, 2, 9, 13, 45), nan),
#    (datetime.datetime(2151, 2, 9, 14, 45), nan),
#    (datetime.datetime(2151, 2, 9, 15, 45), nan),
#    (datetime.datetime(2151, 2, 9, 16, 45), nan),
#    (datetime.datetime(2151, 2, 9, 17, 45), nan),
#    (datetime.datetime(2151, 2, 9, 18, 45), nan),
#    (datetime.datetime(2151, 2, 9, 19, 45), nan),
#    (datetime.datetime(2151, 2, 9, 20, 45), nan),
#    (datetime.datetime(2151, 2, 9, 21, 45), nan),
#    (datetime.datetime(2151, 2, 9, 22, 45), nan),
#    (datetime.datetime(2151, 2, 9, 23, 45), nan),
#    (datetime.datetime(2151, 2, 10, 0, 45), nan),
#    (datetime.datetime(2151, 2, 10, 1, 45), nan),
#    (datetime.datetime(2151, 2, 10, 2, 45), 0.5187729113290301),
#    (datetime.datetime(2151, 2, 10, 3, 45), nan),
#    (datetime.datetime(2151, 2, 10, 4, 45), nan),
#    (datetime.datetime(2151, 2, 10, 5, 45), nan),
#    (datetime.datetime(2151, 2, 10, 6, 45), nan),
#    (datetime.datetime(2151, 2, 10, 7, 45), nan),
#    (datetime.datetime(2151, 2, 10, 8, 45), nan),
#    (datetime.datetime(2151, 2, 10, 9, 45), nan),
#    (datetime.datetime(2151, 2, 10, 10, 45), nan),
#    (datetime.datetime(2151, 2, 10, 11, 45), nan),
#    (datetime.datetime(2151, 2, 10, 12, 45), nan)]}}

# %%
# Make 3D Tensor for input data
input_tensor = list()

for hadm_id in hadm_input_norm:
  fs = hadm_input_norm[hadm_id]
  for idx, (kk, vs) in enumerate(fs.items()):
    vs = np.array(vs)
    vv = vs[:, 1]
    if idx == 0:
      input_vv = np.array(vv).reshape(-1, 1)
      
    else:
      vv = np.array(vv).reshape(-1, 1)
      input_vv = np.concatenate([input_vv, vv], axis=1)

  print(input_vv.shape)
  input_tensor.append(input_vv)
# Out:
# (221, 13)

# %%
input_tensor
# Out:
# [array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [0.4155405405405405, 0.875, 0.6325757575757576, ..., nan, nan,
#          nan],
#         [0.24662162162162163, 0.6875, 0.5492424242424242, ..., nan, nan,
#          nan],
#         [0.20608108108108109, 0.6875, 0.4734848484848485, ..., nan, nan,
#          nan]], dtype=object)]
